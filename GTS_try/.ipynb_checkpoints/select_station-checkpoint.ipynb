# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #
#file = pd.read_csv('/Users/ll/Downloads/GTS资料/surf2019.csv',chunksize=100,header=None,sep=',',encoding='ISO-8859-1')
#cols=['STATION', 'YEAR', 'MONTH','DAY','HOUR','LATITUDE','LONGITUDE','ELEVATION','N','WD','WS','AT','TD','RH','LP','DP03','NH','H1','RAIN01','RAIN02','RAIN03','RAIN06','RAIN09','RAIN12','RAIN24','MIN_AT','ALR','RAIN032','RAIN062','RAIN122','RAIN242']
#print(cols)
#file = pd.read_csv('/Users/ll/Downloads/GTS资料/surf2019.csv',nrows=10000,usecols=cols,sep=',',encoding='ISO-8859-1')
#file
#for chunk in file:
#    print(chunk)

# %%
#大文件分成若干个小文件
def file_split(filename, file_num, header=True):
    # 获得每个文件需要有的行数
    chunksize = 1000000   #先初始化的chunksize是100W
    data1 = pd.read_table(filename, chunksize = chunksize ,header=None, sep=',',encoding='ISO-8859-1') 
    num = 0
    for chunk in data1:
        num += len(chunk)
    chunksize = round(num / file_num + 1)

    # 需要存的file
    head, tail = os.path.splitext(filename)
    print(head,tail)
    data2 = pd.read_table(filename, chunksize = chunksize ,header=None, sep=',',encoding='ISO-8859-1')
    i = 0 #定文件名
    for chunk in data2:
        chunk.to_csv('{0}_{1}{2}'.format(head, i, tail),header=None,index=False)
        print('保存第{0}个数据'.format(i))
        i += 1

# %%
#file_split('/home/liuli/GTS_GFS_MOS/surf2019.csv', 12, header=False)

# %%
#尝试统计每个站点气象要素的缺测情况（以降水缺测统计为主）
cols=['STATION', 'YEAR', 'MONTH','DAY','HOUR','LATITUDE','LONGITUDE','ELEVATION','N','WD','WS','AT','TD','RH','LP','DP03','NH','H1','RAIN01','RAIN02','RAIN03','RAIN06','RAIN09','RAIN12','RAIN24','MIN_AT','ALR','RAIN032','RAIN062','RAIN122','RAIN242']

file0= pd.read_csv('/home/liuli/GTS_GFS_MOS/surf2018.csv',usecols=cols,sep=',',encoding='ISO-8859-1')
df0=pd.DataFrame(file0)
print(df0)

#df0.count()
#df0['STATION'].value_counts()

#####1.去掉重复的行
df1=df0.drop_duplicates(subset = ['STATION','YEAR','MONTH','DAY','HOUR'],keep='last',inplace=False)
#####2.合并年月日为时间戳，接下来要照年月日小时重新排列数据
periods = pd.PeriodIndex(year=df1['YEAR'], month=df1['MONTH'], day=df1['DAY'], hour=df1['HOUR'],freq="H")
#print(periods)
df1.insert(0,'timeStamp', periods)
#print(df1)
####3.统计每个站点的缺测情况，根据数据完好状况来挑选站点。
num_sta=df1['STATION'].values
#print(num_sta)
#此事件用于循环里面的日期补齐
start='2019-01-01 00:00:00'
end_of_db = '2020-01-01 00:00:00'
date_index = pd.date_range(start, end_of_db, freq = '3h')
date_df = pd.DataFrame(date_index,columns=['timeStamp'])
#print(date_df)
#print(date_df.dtypes)
df1['timeStamp'] = df1['timeStamp'].dt.to_timestamp() #必须要转换timestamp，把object转换为datetime64[ns]类型，为merge做准备
#df1['timeStamp']=pd.to_datetime(df1['timeStamp']) #用了这一句报错，不知道为什么
#print(df1.dtypes)
#cols_data是用于统计有效数据的列
cols_data=['N','WD','WS','AT','TD','RH','LP','DP03','NH','H1','RAIN01','RAIN02','RAIN03','RAIN06','RAIN09','RAIN12','RAIN24','MIN_AT','ALR','RAIN032','RAIN062','RAIN122','RAIN242']

name = 'statistics_valid_data.txt'
f=open(name,'w')

for i in num_sta:   
    df2=df1[df1['STATION'].isin([i])] #先挑出这个站号的行    
    #df2=df2.sort_values(by='timeStamp')#把这个站点按照时间顺序排列
    df2=df2.reset_index(drop=True)
    #print(df2)
    # merge日期补充完整数据
    df2 = pd.merge(date_df,df2, on=['timeStamp'], how='left')    
    #print(df2)
    for co in cols_data:        
        num=df2[co].count()
        rate=num/len(df2)
        if rate>=0.8: 
            line=[]
            line=str(i)+'\t'+str(co)+'\t'+str(rate)+'\n'
            f.write(line)
        #把每种要素的有效率结果存入文件
        #print(i,co,rate)
    del df2
# Out:
# /home/liuli/anaconda3/envs/MOS/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          STATION  YEAR  MONTH  DAY  HOUR  LATITUDE  LONGITUDE  ELEVATION    N  \
# 0          53906  2019      1    1     0     35.52     105.72     1654.0  9.0
# 1          52643  2019      1    1     0     38.83      99.62     2311.0  9.0
# 2          52889  2019      1    1     0     36.05     103.88     1518.0  9.0
# 3          53915  2019      1    1     0     35.55     106.67     1348.0  7.0
# 4          52984  2019      1    1     0     35.58     103.18     1918.0  0.0
# 5          52797  2019      1    1     0     37.18     104.05     1631.0  0.0
# 6          56084  2019      1    1     0     34.07     103.22     2401.0  9.0
# 7          56093  2019      1    1     0     34.43     104.01     2316.0  7.0
# 8          52652  2019      1    1     0     38.93     100.43     1483.0  3.0
# 9          53927  2019      1    1     0     35.22     106.63     1456.0  9.0
# 10         52424  2019      1    1     0     40.53      95.76     1172.0  0.0
# 11         53926  2019      1    1     0     35.40     107.71     1030.0  9.0
# 12         56092  2019      1    1     0     35.00     104.65     1729.0  9.0
# 13         52995  2019      1    1     0     35.53     104.60     1898.0  9.0
# 14         53821  2019      1    1     0     36.58     107.30     1256.0  2.0
# 15         52546  2019      1    1     0     39.37      99.83     1333.0  7.0
# 16         52447  2019      1    1     0     40.00      98.90     1271.0  0.0
# 17         52996  2019      1    1     0     35.38     105.00     2450.0  7.0
# 18         52885  2019      1    1     0     36.75     103.25     2119.0  9.0
# 19         56082  2019      1    1     0     34.58     103.50     2545.0  9.0
# 20         53986  2019      1    1     0     35.31     113.88       73.0  7.0
# 21         53988  2019      1    1     0     35.27     113.67       78.0  9.0
# 22         53989  2019      1    1     0     35.05     113.95       77.0  9.0
# 23         57196  2019      1    1     0     33.45     114.88       44.0  9.0
# 24         57293  2019      1    1     0     32.73     114.98       38.0  9.0
# 25         58017  2019      1    1     0     34.25     116.13       41.0  9.0
# 26         57096  2019      1    1     0     34.53     114.78       60.0  9.0
# 27         53997  2019      1    1     0     35.15     114.18       72.0  9.0
# 28         53998  2019      1    1     0     35.20     114.65       61.0  9.0
# 29         54902  2019      1    1     0     35.90     115.12       50.0  9.0
# ...          ...   ...    ...  ...   ...       ...        ...        ...  ...
# 28825269   51241  2019     12   31    23     45.93      83.60     1078.0  9.0
# 28825270   51655  2019     12   31    23     41.35      86.27      886.0  9.0
# 28825271   51356  2019     12   31    23     44.32      86.05      444.0  9.0
# 28825272   51811  2019     12   31    23     38.43      77.27     1232.0  9.0
# 28825273   51701  2019     12   31    23     40.51      75.40     3507.0  9.0
# 28825274   51730  2019     12   31    23     40.50      81.05     1013.0  9.0
# 28825275   51087  2019     12   31    23     46.98      89.52      810.0  9.0
# 28825276   51438  2019     12   31    23     43.18      81.77     1211.0  9.0
# 28825277   58724  2019     12   31    23     27.52     117.30      264.0  9.0
# 28825278   58839  2019     12   31    23     26.23     118.85       41.0  9.0
# 28825279   58932  2019     12   31    23     25.86     118.93       89.0  9.0
# 28825280   58731  2019     12   31    23     27.92     118.53      275.0  9.0
# 28825281   58935  2019     12   31    23     25.48     118.23      517.0  9.0
# 28825282   58940  2019     12   31    23     26.08     119.33       26.0  9.0
# 28825283   58843  2019     12   31    23     26.88     120.00       11.0  9.0
# 28825284   58824  2019     12   31    23     26.40     117.15      342.0  9.0
# 28825285   58837  2019     12   31    23     26.16     118.15      126.0  9.0
# 28825286   58931  2019     12   31    23     25.72     118.10     1651.0  9.0
# 28825287   59131  2019     12   31    23     24.96     118.36       45.0  9.0
# 28825288   58822  2019     12   31    23     26.83     116.85      342.0  9.0
# 28825289   58928  2019     12   31    23     25.02     117.53      161.0  9.0
# 28825290   58735  2019     12   31    23     27.55     118.78      198.0  9.0
# 28825291   58933  2019     12   31    23     26.91     116.98      871.0  9.0
# 28825292   58828  2019     12   31    23     26.27     117.62      213.0  9.0
# 28825293   58834  2019     12   31    23     26.63     118.15      153.0  9.0
# 28825294   58747  2019     12   31    23     27.15     119.35      900.0  9.0
# 28825295   59137  2019     12   31    23     24.81     118.56       55.0  9.0
# 28825296   58929  2019     12   31    23     25.06     118.15       92.0  9.0
# 28825297   58847  2019     12   31    23     26.08     119.28       85.0  9.0
# 28825298    1358  2019     12   31     6       NaN        NaN        NaN  NaN
#
#              WD   ...     RAIN06  RAIN09  RAIN12  RAIN24  MIN_AT  ALR  \
# 0          40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 1         290.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 2         140.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 3         290.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 4         270.0   ...        NaN     NaN     NaN    -1.0     NaN  NaN
# 5         290.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 6         180.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 7           0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 8         160.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 9         200.0   ...        NaN     NaN     NaN    -1.0     NaN  NaN
# 10        110.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 11        290.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 12        220.0   ...        NaN     NaN     NaN    -1.0     NaN  NaN
# 13        160.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 14        340.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 15        110.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 16        200.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 17        180.0   ...        NaN     NaN     NaN     0.3     NaN  NaN
# 18        360.0   ...        NaN     NaN     NaN    -1.0     NaN  NaN
# 19         40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 20          0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 21         90.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 22          0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 23        340.0   ...        NaN     NaN     NaN     0.1    -3.0  NaN
# 24         70.0   ...        NaN     NaN     NaN     NaN    -1.2  NaN
# 25          0.0   ...        NaN     NaN     NaN     NaN    -4.9  NaN
# 26        140.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 27          0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28          0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 29          0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# ...         ...   ...        ...     ...     ...     ...     ...  ...
# 28825269  200.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825270   90.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825271  180.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825272   70.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825273    0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825274    0.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825275  110.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825276  320.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825277   20.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825278  140.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825279   20.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825280  110.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825281   40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825282  360.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825283  340.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825284   70.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825285  140.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825286  320.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825287  340.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825288   90.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825289  340.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825290   40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825291   40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825292   90.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825293   40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825294   40.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825295  360.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825296   70.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825297  360.0   ...        NaN     NaN     NaN     NaN     NaN  NaN
# 28825298    NaN   ...        NaN     NaN     NaN     NaN     NaN  NaN
#
#           RAIN032  RAIN062  RAIN122  RAIN242
# 0             NaN      NaN      0.0      0.0
# 1             NaN      NaN      0.0      0.0
# 2             NaN      NaN      0.0      0.0
# 3             NaN      NaN      0.0      0.0
# 4             NaN      NaN      0.0     -1.0
# 5             NaN      NaN      0.0      0.0
# 6             NaN      NaN      0.0      0.0
# 7             NaN      NaN      0.0      0.0
# 8             NaN      NaN      0.0      0.0
# 9             NaN      NaN      0.0     -1.0
# 10            NaN      NaN      0.0      0.0
# 11            NaN      NaN      0.0      0.0
# 12            NaN      NaN      0.0     -1.0
# 13            NaN      NaN      0.0      0.0
# 14            NaN      NaN      0.0      0.0
# 15            NaN      NaN      0.0      0.0
# 16            NaN      NaN      0.0      0.0
# 17            NaN      NaN      0.0      0.3
# 18            NaN      NaN      0.0     -1.0
# 19            NaN      NaN      0.0      0.0
# 20            NaN      NaN      0.0      0.0
# 21            NaN      NaN      0.0      0.0
# 22            NaN      NaN      0.0      0.0
# 23            NaN      NaN      0.0      0.1
# 24            NaN      NaN      0.0      0.0
# 25            NaN      NaN      0.0      0.0
# 26            NaN      NaN      0.0      0.0
# 27            NaN      NaN      0.0      0.0
# 28            NaN      NaN      0.0      0.0
# 29            NaN      NaN      0.0      0.0
# ...           ...      ...      ...      ...
# 28825269      NaN      NaN      0.0      0.1
# 28825270      NaN      NaN      0.0      0.0
# 28825271      NaN      NaN      0.0      0.0
# 28825272      NaN      NaN      0.0      0.0
# 28825273      NaN      NaN      0.0      0.0
# 28825274      NaN      NaN      0.0      0.0
# 28825275      NaN      NaN      0.0      0.0
# 28825276      NaN      NaN      0.0      0.0
# 28825277      NaN      NaN      0.0      0.0
# 28825278      NaN      NaN      0.0      0.0
# 28825279      NaN      NaN      0.0      0.0
# 28825280      NaN      NaN      0.0      2.0
# 28825281      NaN      NaN      0.0      0.0
# 28825282      NaN      NaN      0.0      0.0
# 28825283      NaN      NaN      0.0      0.0
# 28825284      NaN      NaN      0.0      0.0
# 28825285      NaN      NaN      0.0      0.3
# 28825286      NaN      NaN      0.0      0.0
# 28825287      NaN      NaN      0.0      0.0
# 28825288      NaN      NaN      0.1      0.3
# 28825289      NaN      NaN      0.5      3.5
# 28825290      NaN      NaN      0.0      0.1
# 28825291      NaN      NaN      0.1      0.5
# 28825292      NaN      NaN      0.0      0.5
# 28825293      NaN      NaN      0.0      0.2
# 28825294      NaN      0.1      0.3      0.4
# 28825295      NaN      NaN      0.0      0.0
# 28825296      NaN      NaN      0.0      0.0
# 28825297      NaN      NaN      0.0      0.0
# 28825298      NaN      NaN      0.0      0.0
#
# [28825299 rows x 31 columns]
# /home/liuli/anaconda3/envs/MOS/lib/python3.5/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print("OK")
