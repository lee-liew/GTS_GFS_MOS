# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import r2_score, explained_variance_score, mean_squared_error, mean_absolute_error

# %%
def prep_clf(obs,pre, threshold=0.1):
    '''
    func: 计算二分类结果-混淆矩阵的四个元素
    inputs:
        obs: 观测值，即真实值；
        pre: 预测值；
        threshold: 阈值，判别正负样本的阈值,默认0.1,气象上默认格点 >= 0.1才判定存在降水。
    
    returns:
        hits, misses, falsealarms, correctnegatives
        #aliases: TP, FN, FP, TN 
    '''
    #根据阈值分类为 0, 1
    obs = np.where(obs >= threshold, 1, 0)
    pre = np.where(pre >= threshold, 1, 0)

    # True positive (TP)
    hits = np.sum((obs == 1) & (pre == 1))

    # False negative (FN)
    misses = np.sum((obs == 1) & (pre == 0))

    # False positive (FP)
    falsealarms = np.sum((obs == 0) & (pre == 1))

    # True negative (TN)
    correctnegatives = np.sum((obs == 0) & (pre == 0))

    return hits, misses, falsealarms, correctnegatives


def precision(obs, pre, threshold=0.1):
    '''
    func: 计算精确度precision: TP / (TP + FP)
    inputs:
        obs: 观测值，即真实值；
        pre: 预测值；
        threshold: 阈值，判别正负样本的阈值,默认0.1,气象上默认格点 >= 0.1才判定存在降水。
    
    returns:
        dtype: float
    '''

    TP, FN, FP, TN = prep_clf(obs=obs, pre = pre, threshold=threshold)

    return TP / (TP + FP)


def recall(obs, pre, threshold=0.1):
    '''
    func: 计算召回率recall: TP / (TP + FN)
    inputs:
        obs: 观测值，即真实值；
        pre: 预测值；
        threshold: 阈值，判别正负样本的阈值,默认0.1,气象上默认格点 >= 0.1才判定存在降水。
    
    returns:
        dtype: float
    '''

    TP, FN, FP, TN = prep_clf(obs=obs, pre = pre, threshold=threshold)

    return TP / (TP + FN)


def ACC(obs, pre, threshold=0.1):
    '''
    func: 计算准确度Accuracy: (TP + TN) / (TP + TN + FP + FN)
    inputs:
        obs: 观测值，即真实值；
        pre: 预测值；
        threshold: 阈值，判别正负样本的阈值,默认0.1,气象上默认格点 >= 0.1才判定存在降水。
    
    returns:
        dtype: float
    '''

    TP, FN, FP, TN = prep_clf(obs=obs, pre = pre, threshold=threshold)

    return (TP + TN) / (TP + TN + FP + FN)

def FSC(obs, pre, threshold=0.1):
    '''
    func:计算f1 score = 2 * ((precision * recall) / (precision + recall))
    '''
    precision_socre = precision(obs, pre, threshold=threshold)
    recall_score = recall(obs, pre, threshold=threshold)

    return 2 * ((precision_socre * recall_score) / (precision_socre + recall_score))
def TS(obs, pre, threshold=0.1):
    
    '''
    func: 计算TS评分: TS = hits/(hits + falsealarms + misses) 
    	  alias: TP/(TP+FP+FN)
    inputs:
        obs: 观测值，即真实值；
        pre: 预测值；
        threshold: 阈值，判别正负样本的阈值,默认0.1,气象上默认格点 >= 0.1才判定存在降水。
    returns:
        dtype: float
    '''

    hits, misses, falsealarms, correctnegatives = prep_clf(obs=obs, pre = pre, threshold=threshold)

    return hits/(hits + falsealarms + misses) 

def func_evaluation(y_real, y_pred, verbose=True):
    """
    y_real: real values
    y_pred: prediction values
    MAKE THEM HAVE THE SHAPE OF (N,) FIRST BY USING ndarray.ravel()
    """
    if not isinstance(y_real, np.ndarray):
        y_real = np.array(y_real)
    if not isinstance(y_pred, np.ndarray):
        y_pred = np.array(y_pred)
    y_real = y_real.ravel()
    y_pred = y_pred.ravel()

    # MAPE
    def cal_mape(y_true, y_pred):
        #y_true = np.where(y_true == 0, 0.1, y_true)  # To avoid zeros.
        mape = np.mean(abs((y_true.ravel() - y_pred.ravel()) / y_true.ravel()))
        return mape

    m0 = stats.pearsonr(y_real, y_pred)[0]
    m1 = r2_score(y_real, y_pred)
    m2 = explained_variance_score(y_real, y_pred)
    m3 = mean_squared_error(y_real, y_pred)
    m3 = np.sqrt(m3)
    m4 = mean_absolute_error(y_real, y_pred)
    m5 = cal_mape(y_real, y_pred)
    if verbose:
        print("模型的评估结果:")
        print(
            'PersonR: %f \nR2: %f \nExplained Variance: %f \nRMSE: %f \nMAE: %f \nMAPE: %f'
            % (m0, m1, m2, m3, m4, m5))
    return m0,m1, m2, m3, m4, m5

# %%
path='/home/liuli/GTS_GFS_MOS/multi_para_mos/evaluate/wave/'
model=['catboost','lgboost','RandomForest','xgboost']
#ts=np.array([])
m0=np.array([])
m3=np.array([])
m4=np.array([])

for cc in range(0,len(model)):   
    mulu = glob.glob(path+model[cc]+'/*')
    mulu.sort()
    for ii,file in enumerate(mulu):
        filedata= pd.read_csv(file,sep=',')
        df=pd.DataFrame(filedata)
        df=df.fillna(0)
        #print(df)
        #df中pre和true间隔排列，共40行，80列，开始计算TS评分
        for i in range(1,41):
            col_pre='pre_%i' % i       
            col_obs='tru_%i' % i
            
            #ts=np.append(ts,TS(df[col_obs],df[col_pre], threshold=0.1))
            m0_temp, m1_temp, m2_temp, m3_temp, m4_temp, m5_temp=func_evaluation(df[col_obs],df[col_pre])
            m0=np.append(m0,m0_temp)
            m3=np.append(m3,m3_temp)
            m4=np.append(m4,m4_temp)

print(m0)
# Out:
# 模型的评估结果:
# PersonR: 0.351358
# R2: -5.542503
# Explained Variance: 0.109279
# RMSE: 10.380730
# MAE: 9.648252
# MAPE: 0.755939
# 模型的评估结果:
# PersonR: 0.414335
# R2: -4.668042
# Explained Variance: 0.135455
# RMSE: 9.887082
# MAE: 9.101864
# MAPE: 0.739210
# 模型的评估结果:
# PersonR: 0.468620
# R2: -4.745036
# Explained Variance: 0.171407
# RMSE: 9.395829
# MAE: 8.691890
# MAPE: 0.735224
# 模型的评估结果:
# PersonR: 0.365666
# R2: -4.946956
# Explained Variance: 0.119554
# RMSE: 9.455071
# MAE: 8.727139
# MAPE: 0.746035
# 模型的评估结果:
# PersonR: 0.351341
# R2: -4.810219
# Explained Variance: 0.112972
# RMSE: 9.499445
# MAE: 8.744305
# MAPE: 0.756927
# 模型的评估结果:
# PersonR: 0.495930
# R2: -4.889659
# Explained Variance: 0.194739
# RMSE: 9.105386
# MAE: 8.460052
# MAPE: 0.761780
# 模型的评估结果:
# PersonR: 0.497047
# R2: -5.766573
# Explained Variance: 0.200576
# RMSE: 8.895623
# MAE: 8.353634
# MAPE: 0.774350
# 模型的评估结果:
# PersonR: 0.491072
# R2: -6.248948
# Explained Variance: 0.188730
# RMSE: 8.763145
# MAE: 8.258232
# MAPE: 0.779139
# 模型的评估结果:
# PersonR: 0.451906
# R2: -5.523817
# Explained Variance: 0.185213
# RMSE: 8.191903
# MAE: 7.663287
# MAPE: 0.734581
# 模型的评估结果:
# PersonR: 0.372050
# R2: -5.330903
# Explained Variance: 0.134334
# RMSE: 8.155485
# MAE: 7.577422
# MAPE: 0.736235
# 模型的评估结果:
# PersonR: 0.261789
# R2: -6.344219
# Explained Variance: 0.061096
# RMSE: 8.052022
# MAE: 7.519733
# MAPE: 0.740496
# 模型的评估结果:
# PersonR: 0.277558
# R2: -6.455556
# Explained Variance: 0.070578
# RMSE: 7.916105
# MAE: 7.406269
# MAPE: 0.755318
# 模型的评估结果:
# PersonR: 0.397032
# R2: -5.731772
# Explained Variance: 0.155723
# RMSE: 7.782290
# MAE: 7.277932
# MAPE: 0.763428
# 模型的评估结果:
# PersonR: 0.556336
# R2: -5.113931
# Explained Variance: 0.256772
# RMSE: 7.700073
# MAE: 7.216891
# MAPE: 0.782720
# 模型的评估结果:
# PersonR: 0.583352
# R2: -5.123967
# Explained Variance: 0.261657
# RMSE: 7.697531
# MAE: 7.218601
# MAPE: 0.796511
# 模型的评估结果:
# PersonR: 0.622630
# R2: -5.596674
# Explained Variance: 0.285588
# RMSE: 7.481139
# MAE: 7.064434
# MAPE: 0.819461
# 模型的评估结果:
# PersonR: 0.543426
# R2: -4.734097
# Explained Variance: 0.234659
# RMSE: 7.065634
# MAE: 6.622633
# MAPE: 0.812072
# 模型的评估结果:
# PersonR: 0.555862
# R2: -3.774962
# Explained Variance: 0.235388
# RMSE: 6.683340
# MAE: 6.158915
# MAPE: 0.770519
# 模型的评估结果:
# PersonR: 0.492256
# R2: -3.159464
# Explained Variance: 0.198509
# RMSE: 6.477494
# MAE: 5.906057
# MAPE: 0.801906
# 模型的评估结果:
# PersonR: 0.513727
# R2: -2.689363
# Explained Variance: 0.206844
# RMSE: 6.455925
# MAE: 5.822145
# MAPE: 0.869611
# 模型的评估结果:
# PersonR: 0.608163
# R2: -2.295096
# Explained Variance: 0.256980
# RMSE: 6.325705
# MAE: 5.597059
# MAPE: 0.757122
# 模型的评估结果:
# PersonR: 0.637736
# R2: -2.037928
# Explained Variance: 0.245253
# RMSE: 6.292470
# MAE: 5.524836
# MAPE: 0.790111
# 模型的评估结果:
# PersonR: 0.660528
# R2: -1.790826
# Explained Variance: 0.221371
# RMSE: 6.452061
# MAE: 5.703518
# MAPE: 0.967760
# 模型的评估结果:
# PersonR: 0.708192
# R2: -1.516832
# Explained Variance: 0.219982
# RMSE: 6.436697
# MAE: 5.632976
# MAPE: 0.970831
# 模型的评估结果:
# PersonR: 0.685954
# R2: -1.148705
# Explained Variance: 0.216168
# RMSE: 6.317703
# MAE: 5.484938
# MAPE: 0.957107
# 模型的评估结果:
# PersonR: 0.724422
# R2: -0.823798
# Explained Variance: 0.253375
# RMSE: 6.047515
# MAE: 5.237687
# MAPE: 1.066943
# 模型的评估结果:
# PersonR: 0.711763
# R2: -0.619181
# Explained Variance: 0.251575
# RMSE: 5.855502
# MAE: 4.988957
# MAPE: 0.961296
# 模型的评估结果:
# PersonR: 0.758192
# R2: -0.462320
# Explained Variance: 0.269127
# RMSE: 5.613182
# MAE: 4.815331
# MAPE: 1.046462
# 模型的评估结果:
# PersonR: 0.714138
# R2: -0.353412
# Explained Variance: 0.262332
# RMSE: 5.433415
# MAE: 4.502655
# MAPE: 0.940052
# 模型的评估结果:
# PersonR: 0.722821
# R2: -0.251440
# Explained Variance: 0.262717
# RMSE: 5.275969
# MAE: 4.284211
# MAPE: 0.847774
# 模型的评估结果:
# PersonR: 0.748033
# R2: -0.139604
# Explained Variance: 0.284825
# RMSE: 5.052710
# MAE: 4.134219
# MAPE: 0.866946
# 模型的评估结果:
# PersonR: 0.746867
# R2: -0.068258
# Explained Variance: 0.273410
# RMSE: 4.967052
# MAE: 4.163764
# MAPE: 0.965685
# 模型的评估结果:
# PersonR: 0.747031
# R2: -0.018230
# Explained Variance: 0.279263
# RMSE: 4.915185
# MAE: 4.149650
# MAPE: 1.113301
# 模型的评估结果:
# PersonR: 0.723459
# R2: 0.077176
# Explained Variance: 0.286925
# RMSE: 4.706278
# MAE: 3.950822
# MAPE: 1.087298
# 模型的评估结果:
# PersonR: 0.728974
# R2: 0.170310
# Explained Variance: 0.313128
# RMSE: 4.444955
# MAE: 3.631232
# MAPE: 1.042695
# 模型的评估结果:
# PersonR: 0.697829
# R2: 0.242099
# Explained Variance: 0.316465
# RMSE: 4.196180
# MAE: 3.438292
# MAPE: 1.084236
# 模型的评估结果:
# PersonR: 0.643400
# R2: 0.300453
# Explained Variance: 0.325157
# RMSE: 3.696584
# MAE: 3.019860
# MAPE: 1.080095
# 模型的评估结果:
# PersonR: 0.713244
# R2: 0.350417
# Explained Variance: 0.369919
# RMSE: 3.638941
# MAE: 3.010056
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.672830
# R2: 0.334630
# Explained Variance: 0.335305
# RMSE: 3.672896
# MAE: 3.030291
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.612671
# R2: 0.299844
# Explained Variance: 0.323308
# RMSE: 3.345381
# MAE: 2.702766
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.052661
# R2: -3.833934
# Explained Variance: -0.100196
# RMSE: 9.899205
# MAE: 8.913971
# MAPE: 0.877436
# 模型的评估结果:
# PersonR: -0.089385
# R2: -2.985230
# Explained Variance: -0.094810
# RMSE: 9.538761
# MAE: 8.533984
# MAPE: 0.905887
# 模型的评估结果:
# PersonR: -0.007299
# R2: -2.660132
# Explained Variance: -0.054264
# RMSE: 9.114707
# MAE: 8.009214
# MAPE: 0.831811
# 模型的评估结果:
# PersonR: -0.039282
# R2: -2.762050
# Explained Variance: -0.080919
# RMSE: 9.079232
# MAE: 7.875756
# MAPE: 0.810673
# 模型的评估结果:
# PersonR: 0.091807
# R2: -2.604322
# Explained Variance: -0.015029
# RMSE: 8.827614
# MAE: 7.645195
# MAPE: 0.811979
# 模型的评估结果:
# PersonR: 0.121205
# R2: -2.447170
# Explained Variance: -0.003017
# RMSE: 8.400233
# MAE: 7.251111
# MAPE: 0.786294
# 模型的评估结果:
# PersonR: 0.084239
# R2: -2.368055
# Explained Variance: -0.029456
# RMSE: 8.023544
# MAE: 7.095545
# MAPE: 0.933242
# 模型的评估结果:
# PersonR: 0.087553
# R2: -2.479175
# Explained Variance: -0.033297
# RMSE: 7.740998
# MAE: 6.898558
# MAPE: 0.908759
# 模型的评估结果:
# PersonR: 0.085281
# R2: -2.187930
# Explained Variance: -0.039395
# RMSE: 7.213688
# MAE: 6.379447
# MAPE: 0.895901
# 模型的评估结果:
# PersonR: 0.088030
# R2: -2.213307
# Explained Variance: -0.042587
# RMSE: 7.216702
# MAE: 6.411644
# MAPE: 0.910806
# 模型的评估结果:
# PersonR: 0.173907
# R2: -2.132195
# Explained Variance: 0.004231
# RMSE: 7.132425
# MAE: 6.220148
# MAPE: 0.857600
# 模型的评估结果:
# PersonR: 0.263529
# R2: -2.128159
# Explained Variance: 0.055006
# RMSE: 7.097773
# MAE: 6.196013
# MAPE: 0.842664
# 模型的评估结果:
# PersonR: 0.172588
# R2: -2.208467
# Explained Variance: -0.025158
# RMSE: 6.678812
# MAE: 5.803079
# MAPE: 0.806377
# 模型的评估结果:
# PersonR: 0.141513
# R2: -1.649171
# Explained Variance: -0.026793
# RMSE: 6.371954
# MAE: 5.618694
# MAPE: 0.858582
# 模型的评估结果:
# PersonR: 0.098558
# R2: -1.462689
# Explained Variance: -0.055967
# RMSE: 6.353932
# MAE: 5.543142
# MAPE: 0.925926
# 模型的评估结果:
# PersonR: 0.057075
# R2: -1.406783
# Explained Variance: -0.080001
# RMSE: 6.355883
# MAE: 5.365898
# MAPE: 0.878408
# 模型的评估结果:
# PersonR: 0.027883
# R2: -1.038321
# Explained Variance: -0.088709
# RMSE: 6.098603
# MAE: 5.134630
# MAPE: 0.808484
# 模型的评估结果:
# PersonR: 0.019308
# R2: -0.704606
# Explained Variance: -0.078971
# RMSE: 5.941083
# MAE: 4.980136
# MAPE: 0.870736
# 模型的评估结果:
# PersonR: 0.067704
# R2: -0.462132
# Explained Variance: -0.042645
# RMSE: 5.756371
# MAE: 4.950744
# MAPE: 0.931608
# 模型的评估结果:
# PersonR: 0.105277
# R2: -0.379716
# Explained Variance: -0.039188
# RMSE: 5.384092
# MAE: 4.729514
# MAPE: 1.040415
# 模型的评估结果:
# PersonR: -0.123985
# R2: -0.353477
# Explained Variance: -0.186492
# RMSE: 5.763683
# MAE: 5.031537
# MAPE: 1.127292
# 模型的评估结果:
# PersonR: -0.066016
# R2: -0.251201
# Explained Variance: -0.136331
# RMSE: 6.091036
# MAE: 5.295648
# MAPE: 1.087372
# 模型的评估结果:
# PersonR: 0.106138
# R2: -0.134578
# Explained Variance: -0.027259
# RMSE: 6.062534
# MAE: 5.309850
# MAPE: 1.044167
# 模型的评估结果:
# PersonR: 0.114532
# R2: -0.091461
# Explained Variance: -0.012013
# RMSE: 6.106623
# MAE: 5.376962
# MAPE: 1.038936
# 模型的评估结果:
# PersonR: 0.150884
# R2: -0.051476
# Explained Variance: -0.001199
# RMSE: 6.081132
# MAE: 5.103703
# MAPE: 0.926671
# 模型的评估结果:
# PersonR: 0.098216
# R2: -0.059547
# Explained Variance: -0.043481
# RMSE: 6.329641
# MAE: 5.364824
# MAPE: 0.980845
# 模型的评估结果:
# PersonR: 0.188050
# R2: 0.015492
# Explained Variance: 0.017140
# RMSE: 6.289845
# MAE: 5.234819
# MAPE: 1.051728
# 模型的评估结果:
# PersonR: 0.332226
# R2: 0.109032
# Explained Variance: 0.110329
# RMSE: 6.073159
# MAE: 5.021657
# MAPE: 0.831233
# 模型的评估结果:
# PersonR: 0.362738
# R2: 0.125573
# Explained Variance: 0.130981
# RMSE: 5.941399
# MAE: 5.013685
# MAPE: 0.981259
# 模型的评估结果:
# PersonR: 0.351623
# R2: 0.099911
# Explained Variance: 0.120053
# RMSE: 5.969568
# MAE: 4.886215
# MAPE: 1.054287
# 模型的评估结果:
# PersonR: 0.359691
# R2: 0.084968
# Explained Variance: 0.127330
# RMSE: 5.922816
# MAE: 4.859599
# MAPE: 0.985918
# 模型的评估结果:
# PersonR: 0.236181
# R2: -0.052980
# Explained Variance: 0.017259
# RMSE: 6.466720
# MAE: 5.473545
# MAPE: 1.333024
# 模型的评估结果:
# PersonR: 0.212993
# R2: -0.114786
# Explained Variance: -0.011508
# RMSE: 6.637571
# MAE: 5.576462
# MAPE: 1.213813
# 模型的评估结果:
# PersonR: 0.194938
# R2: -0.181151
# Explained Variance: -0.022784
# RMSE: 6.951102
# MAE: 6.130880
# MAPE: 1.544895
# 模型的评估结果:
# PersonR: 0.179720
# R2: -0.270806
# Explained Variance: -0.031143
# RMSE: 7.144885
# MAE: 6.195110
# MAPE: 1.552155
# 模型的评估结果:
# PersonR: 0.178606
# R2: -0.347035
# Explained Variance: -0.031949
# RMSE: 7.221320
# MAE: 6.264948
# MAPE: 1.392787
# 模型的评估结果:
# PersonR: 0.011584
# R2: -0.571340
# Explained Variance: -0.193495
# RMSE: 7.803783
# MAE: 6.767654
# MAPE: 1.454028
# 模型的评估结果:
# PersonR: 0.008393
# R2: -1.126194
# Explained Variance: -0.298244
# RMSE: 7.953617
# MAE: 6.804342
# MAPE: 1.830319
# 模型的评估结果:
# PersonR: 0.128096
# R2: -0.702022
# Explained Variance: -0.109550
# RMSE: 7.513013
# MAE: 6.115077
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.133599
# R2: -1.025145
# Explained Variance: -0.141590
# RMSE: 7.556402
# MAE: 6.174670
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.925743
# R2: -12.311327
# Explained Variance: 0.854126
# RMSE: 9.473355
# MAE: 9.421305
# MAPE: 0.704131
# 模型的评估结果:
# PersonR: 0.881137
# R2: -10.500025
# Explained Variance: 0.776393
# RMSE: 9.205808
# MAE: 9.115869
# MAPE: 0.692599
# 模型的评估结果:
# PersonR: 0.820472
# R2: -8.737983
# Explained Variance: 0.673016
# RMSE: 9.165027
# MAE: 9.009841
# MAPE: 0.696297
# 模型的评估结果:
# PersonR: 0.795122
# R2: -7.109253
# Explained Variance: 0.624847
# RMSE: 8.723417
# MAE: 8.519245
# MAPE: 0.680558
# 模型的评估结果:
# PersonR: 0.750111
# R2: -6.528735
# Explained Variance: 0.562011
# RMSE: 8.802791
# MAE: 8.542900
# MAPE: 0.695181
# 模型的评估结果:
# PersonR: 0.756856
# R2: -5.051499
# Explained Variance: 0.571753
# RMSE: 8.431255
# MAE: 8.127454
# MAPE: 0.681148
# 模型的评估结果:
# PersonR: 0.773955
# R2: -4.221157
# Explained Variance: 0.596831
# RMSE: 8.137506
# MAE: 7.817013
# MAPE: 0.675946
# 模型的评估结果:
# PersonR: 0.780087
# R2: -3.817574
# Explained Variance: 0.601314
# RMSE: 8.127274
# MAE: 7.783720
# MAPE: 0.697085
# 模型的评估结果:
# PersonR: 0.805987
# R2: -3.017190
# Explained Variance: 0.622627
# RMSE: 7.618389
# MAE: 7.251732
# MAPE: 0.655000
# 模型的评估结果:
# PersonR: 0.777931
# R2: -2.701356
# Explained Variance: 0.585627
# RMSE: 7.257253
# MAE: 6.838968
# MAPE: 0.630544
# 模型的评估结果:
# PersonR: 0.754719
# R2: -2.627158
# Explained Variance: 0.563898
# RMSE: 6.952495
# MAE: 6.521156
# MAPE: 0.614796
# 模型的评估结果:
# PersonR: 0.754686
# R2: -2.364518
# Explained Variance: 0.569409
# RMSE: 6.693899
# MAE: 6.250897
# MAPE: 0.603057
# 模型的评估结果:
# PersonR: 0.738703
# R2: -2.185823
# Explained Variance: 0.545677
# RMSE: 6.473488
# MAE: 6.060758
# MAPE: 0.595316
# 模型的评估结果:
# PersonR: 0.743328
# R2: -1.698846
# Explained Variance: 0.552458
# RMSE: 5.894434
# MAE: 5.520952
# MAPE: 0.561076
# 模型的评估结果:
# PersonR: 0.729803
# R2: -1.424972
# Explained Variance: 0.532612
# RMSE: 5.716942
# MAE: 5.278335
# MAPE: 0.544024
# 模型的评估结果:
# PersonR: 0.693056
# R2: -1.250677
# Explained Variance: 0.471483
# RMSE: 5.403825
# MAE: 4.918569
# MAPE: 0.516457
# 模型的评估结果:
# PersonR: 0.660174
# R2: -1.211566
# Explained Variance: 0.426750
# RMSE: 5.320489
# MAE: 4.690395
# MAPE: 0.491987
# 模型的评估结果:
# PersonR: 0.661674
# R2: -0.908113
# Explained Variance: 0.430154
# RMSE: 4.952373
# MAE: 4.304118
# MAPE: 0.459737
# 模型的评估结果:
# PersonR: 0.670885
# R2: -0.716276
# Explained Variance: 0.444225
# RMSE: 4.746758
# MAE: 4.157800
# MAPE: 0.467760
# 模型的评估结果:
# PersonR: 0.622886
# R2: -0.676111
# Explained Variance: 0.371278
# RMSE: 4.598376
# MAE: 4.023909
# MAPE: 0.464504
# 模型的评估结果:
# PersonR: 0.571440
# R2: -0.664463
# Explained Variance: 0.293604
# RMSE: 4.551824
# MAE: 4.041464
# MAPE: 0.479385
# 模型的评估结果:
# PersonR: 0.545429
# R2: -0.678034
# Explained Variance: 0.260882
# RMSE: 4.544089
# MAE: 4.071976
# MAPE: 0.482895
# 模型的评估结果:
# PersonR: 0.521035
# R2: -0.900895
# Explained Variance: 0.205644
# RMSE: 4.535980
# MAE: 4.039580
# MAPE: 0.490907
# 模型的评估结果:
# PersonR: 0.548345
# R2: -0.801391
# Explained Variance: 0.242510
# RMSE: 4.343946
# MAE: 3.855007
# MAPE: 0.482195
# 模型的评估结果:
# PersonR: 0.490145
# R2: -0.776139
# Explained Variance: 0.134111
# RMSE: 4.159405
# MAE: 3.582754
# MAPE: 0.455743
# 模型的评估结果:
# PersonR: 0.453975
# R2: -0.802524
# Explained Variance: 0.073416
# RMSE: 3.888037
# MAE: 3.370737
# MAPE: 0.439604
# 模型的评估结果:
# PersonR: 0.447022
# R2: -0.771125
# Explained Variance: 0.014726
# RMSE: 3.608854
# MAE: 3.173998
# MAPE: 0.432215
# 模型的评估结果:
# PersonR: 0.470941
# R2: -0.479055
# Explained Variance: 0.052819
# RMSE: 3.284246
# MAE: 2.752395
# MAPE: 0.387170
# 模型的评估结果:
# PersonR: 0.629419
# R2: -0.004081
# Explained Variance: 0.346056
# RMSE: 2.771247
# MAE: 2.287611
# MAPE: 0.322725
# 模型的评估结果:
# PersonR: 0.655487
# R2: 0.258561
# Explained Variance: 0.401072
# RMSE: 2.391110
# MAE: 1.833175
# MAPE: 0.260649
# 模型的评估结果:
# PersonR: 0.671979
# R2: 0.407479
# Explained Variance: 0.441046
# RMSE: 2.141915
# MAE: 1.686431
# MAPE: 0.246768
# 模型的评估结果:
# PersonR: 0.659981
# R2: 0.427587
# Explained Variance: 0.433086
# RMSE: 2.046804
# MAE: 1.632488
# MAPE: 0.278865
# 模型的评估结果:
# PersonR: 0.671559
# R2: 0.433912
# Explained Variance: 0.440317
# RMSE: 1.913228
# MAE: 1.647183
# MAPE: 0.337361
# 模型的评估结果:
# PersonR: 0.574031
# R2: 0.242994
# Explained Variance: 0.324772
# RMSE: 2.198842
# MAE: 1.940508
# MAPE: 0.458947
# 模型的评估结果:
# PersonR: 0.454870
# R2: -0.111008
# Explained Variance: 0.162183
# RMSE: 2.488960
# MAE: 2.238296
# MAPE: 0.575578
# 模型的评估结果:
# PersonR: 0.391649
# R2: -0.425835
# Explained Variance: 0.080980
# RMSE: 2.694351
# MAE: 2.385564
# MAPE: 0.743030
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# 模型的评估结果:
# PersonR: 0.429704
# R2: -0.685570
# Explained Variance: 0.158603
# RMSE: 3.072472
# MAE: 2.619590
# MAPE: 0.906675
# 模型的评估结果:
# PersonR: 0.490343
# R2: -1.396960
# Explained Variance: 0.138128
# RMSE: 3.409616
# MAE: 2.961046
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.633679
# R2: -0.900761
# Explained Variance: 0.302274
# RMSE: 3.365162
# MAE: 2.787741
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.685464
# R2: -0.597863
# Explained Variance: 0.349618
# RMSE: 3.321996
# MAE: 2.698660
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.326325
# R2: -14.441598
# Explained Variance: -0.198346
# RMSE: 16.955677
# MAE: 16.284469
# MAPE: 0.699996
# 模型的评估结果:
# PersonR: -0.323266
# R2: -14.744596
# Explained Variance: -0.191768
# RMSE: 16.887405
# MAE: 16.235693
# MAPE: 0.705026
# 模型的评估结果:
# PersonR: -0.218578
# R2: -14.005092
# Explained Variance: -0.143059
# RMSE: 16.739095
# MAE: 16.088891
# MAPE: 0.705521
# 模型的评估结果:
# PersonR: -0.125547
# R2: -12.560047
# Explained Variance: -0.093104
# RMSE: 16.240931
# MAE: 15.572571
# MAPE: 0.689208
# 模型的评估结果:
# PersonR: -0.130896
# R2: -13.232552
# Explained Variance: -0.106210
# RMSE: 16.410757
# MAE: 15.760105
# MAPE: 0.707794
# 模型的评估结果:
# PersonR: -0.072333
# R2: -13.286095
# Explained Variance: -0.084833
# RMSE: 16.173638
# MAE: 15.547432
# MAPE: 0.707704
# 模型的评估结果:
# PersonR: 0.005135
# R2: -13.385014
# Explained Variance: -0.046779
# RMSE: 15.792003
# MAE: 15.206570
# MAPE: 0.697581
# 模型的评估结果:
# PersonR: -0.023991
# R2: -14.111253
# Explained Variance: -0.062802
# RMSE: 15.835897
# MAE: 15.268862
# MAPE: 0.707923
# 模型的评估结果:
# PersonR: 0.013247
# R2: -13.981046
# Explained Variance: -0.043867
# RMSE: 15.363057
# MAE: 14.818151
# MAPE: 0.695935
# 模型的评估结果:
# PersonR: -0.026394
# R2: -14.871368
# Explained Variance: -0.063586
# RMSE: 15.073929
# MAE: 14.560098
# MAPE: 0.694479
# 模型的评估结果:
# PersonR: 0.033620
# R2: -14.548866
# Explained Variance: -0.038988
# RMSE: 14.917195
# MAE: 14.410189
# MAPE: 0.692932
# 模型的评估结果:
# PersonR: 0.016312
# R2: -15.321242
# Explained Variance: -0.055799
# RMSE: 14.534013
# MAE: 14.056062
# MAPE: 0.682858
# 模型的评估结果:
# PersonR: 0.020173
# R2: -16.815071
# Explained Variance: -0.059462
# RMSE: 14.111391
# MAE: 13.685358
# MAPE: 0.677531
# 模型的评估结果:
# PersonR: -0.016485
# R2: -17.399050
# Explained Variance: -0.070891
# RMSE: 13.400362
# MAE: 13.004541
# MAPE: 0.649566
# 模型的评估结果:
# PersonR: 0.037816
# R2: -18.799206
# Explained Variance: -0.059117
# RMSE: 13.107809
# MAE: 12.752404
# MAPE: 0.646867
# 模型的评估结果:
# PersonR: 0.059166
# R2: -17.458246
# Explained Variance: -0.034874
# RMSE: 12.577211
# MAE: 12.219551
# MAPE: 0.627008
# 模型的评估结果:
# PersonR: 0.029601
# R2: -16.542220
# Explained Variance: -0.053654
# RMSE: 12.657666
# MAE: 12.271646
# MAPE: 0.634979
# 模型的评估结果:
# PersonR: 0.012003
# R2: -16.644179
# Explained Variance: -0.063264
# RMSE: 12.238129
# MAE: 11.863656
# MAPE: 0.620317
# 模型的评估结果:
# PersonR: 0.044909
# R2: -18.960015
# Explained Variance: -0.061906
# RMSE: 11.975703
# MAE: 11.652785
# MAPE: 0.616106
# 模型的评估结果:
# PersonR: 0.228157
# R2: -24.294560
# Explained Variance: 0.036133
# RMSE: 11.848184
# MAE: 11.620250
# MAPE: 0.622416
# 模型的评估结果:
# PersonR: 0.250984
# R2: -29.183088
# Explained Variance: 0.042385
# RMSE: 11.760460
# MAE: 11.572395
# MAPE: 0.625189
# 模型的评估结果:
# PersonR: 0.344155
# R2: -33.825250
# Explained Variance: 0.110214
# RMSE: 11.574298
# MAE: 11.425479
# MAPE: 0.628218
# 模型的评估结果:
# PersonR: 0.354327
# R2: -26.651328
# Explained Variance: 0.123992
# RMSE: 11.493604
# MAE: 11.310077
# MAPE: 0.632686
# 模型的评估结果:
# PersonR: 0.211962
# R2: -17.860753
# Explained Variance: 0.035816
# RMSE: 11.378965
# MAE: 11.084297
# MAPE: 0.622185
# 模型的评估结果:
# PersonR: 0.069544
# R2: -14.048991
# Explained Variance: -0.052511
# RMSE: 11.242123
# MAE: 10.841866
# MAPE: 0.610576
# 模型的评估结果:
# PersonR: 0.030089
# R2: -13.526662
# Explained Variance: -0.092730
# RMSE: 11.351897
# MAE: 10.916593
# MAPE: 0.617926
# 模型的评估结果:
# PersonR: 0.144343
# R2: -12.057215
# Explained Variance: -0.009312
# RMSE: 11.176420
# MAE: 10.735769
# MAPE: 0.612459
# 模型的评估结果:
# PersonR: 0.343830
# R2: -10.178232
# Explained Variance: 0.116330
# RMSE: 10.969741
# MAE: 10.527222
# MAPE: 0.604077
# 模型的评估结果:
# PersonR: 0.551848
# R2: -9.203413
# Explained Variance: 0.251590
# RMSE: 10.774366
# MAE: 10.371697
# MAPE: 0.601851
# 模型的评估结果:
# PersonR: 0.620622
# R2: -8.264857
# Explained Variance: 0.301767
# RMSE: 10.434518
# MAE: 10.033625
# MAPE: 0.586006
# 模型的评估结果:
# PersonR: 0.472265
# R2: -7.954303
# Explained Variance: 0.200015
# RMSE: 10.214032
# MAE: 9.747093
# MAPE: 0.570443
# 模型的评估结果:
# PersonR: 0.302672
# R2: -8.427573
# Explained Variance: 0.090274
# RMSE: 10.421922
# MAE: 9.906330
# MAPE: 0.579952
# 模型的评估结果:
# PersonR: 0.164288
# R2: -8.562072
# Explained Variance: -0.000260
# RMSE: 10.435143
# MAE: 9.886588
# MAPE: 0.577151
# 模型的评估结果:
# PersonR: 0.163604
# R2: -8.026821
# Explained Variance: 0.000170
# RMSE: 10.351034
# MAE: 9.760964
# MAPE: 0.572899
# 模型的评估结果:
# PersonR: 0.243673
# R2: -6.586484
# Explained Variance: 0.057044
# RMSE: 9.785347
# MAE: 9.157044
# MAPE: 0.541666
# 模型的评估结果:
# PersonR: 0.277152
# R2: -6.117669
# Explained Variance: 0.076606
# RMSE: 9.489234
# MAE: 8.852328
# MAPE: 0.529892
# 模型的评估结果:
# PersonR: 0.264999
# R2: -5.607805
# Explained Variance: 0.069155
# RMSE: 8.996480
# MAE: 8.338769
# MAPE: 0.502988
# 模型的评估结果:
# PersonR: 0.561742
# R2: -3.091219
# Explained Variance: 0.288540
# RMSE: 8.094716
# MAE: 7.357294
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.783001
# R2: -1.221262
# Explained Variance: 0.501002
# RMSE: 7.660422
# MAE: 6.745322
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.835004
# R2: -0.506555
# Explained Variance: 0.568248
# RMSE: 7.227873
# MAE: 6.104955
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.537335
# R2: -28.775140
# Explained Variance: 0.282760
# RMSE: 17.219644
# MAE: 17.010982
# MAPE: 0.786479
# 模型的评估结果:
# PersonR: 0.574801
# R2: -26.352644
# Explained Variance: 0.330095
# RMSE: 17.098687
# MAE: 16.888003
# MAPE: 0.787584
# 模型的评估结果:
# PersonR: 0.474521
# R2: -23.728110
# Explained Variance: 0.216423
# RMSE: 16.936426
# MAE: 16.665928
# MAPE: 0.784066
# 模型的评估结果:
# PersonR: 0.291395
# R2: -21.578411
# Explained Variance: -0.011732
# RMSE: 16.727172
# MAE: 16.348107
# MAPE: 0.776205
# 模型的评估结果:
# PersonR: 0.223988
# R2: -21.658623
# Explained Variance: -0.052602
# RMSE: 16.857543
# MAE: 16.461330
# MAPE: 0.787784
# 模型的评估结果:
# PersonR: 0.375190
# R2: -21.095727
# Explained Variance: 0.118877
# RMSE: 16.834988
# MAE: 16.495904
# MAPE: 0.794114
# 模型的评估结果:
# PersonR: 0.452886
# R2: -21.138586
# Explained Variance: 0.190841
# RMSE: 16.537324
# MAE: 16.232294
# MAPE: 0.792062
# 模型的评估结果:
# PersonR: 0.610090
# R2: -20.423722
# Explained Variance: 0.368886
# RMSE: 16.282985
# MAE: 16.041355
# MAPE: 0.796598
# 模型的评估结果:
# PersonR: 0.606698
# R2: -20.780357
# Explained Variance: 0.366647
# RMSE: 15.616185
# MAE: 15.387458
# MAPE: 0.774676
# 模型的评估结果:
# PersonR: 0.445241
# R2: -20.930875
# Explained Variance: 0.182664
# RMSE: 15.598725
# MAE: 15.305293
# MAPE: 0.770621
# 模型的评估结果:
# PersonR: 0.334141
# R2: -21.184550
# Explained Variance: 0.045317
# RMSE: 15.621246
# MAE: 15.281430
# MAPE: 0.770788
# 模型的评估结果:
# PersonR: 0.391629
# R2: -22.692441
# Explained Variance: 0.087075
# RMSE: 15.296615
# MAE: 14.999013
# MAPE: 0.770270
# 模型的评估结果:
# PersonR: 0.334640
# R2: -24.566809
# Explained Variance: -0.018628
# RMSE: 14.906304
# MAE: 14.606339
# MAPE: 0.762597
# 模型的评估结果:
# PersonR: 0.315640
# R2: -24.512720
# Explained Variance: -0.089437
# RMSE: 14.098052
# MAE: 13.793763
# MAPE: 0.726074
# 模型的评估结果:
# PersonR: 0.261104
# R2: -22.897893
# Explained Variance: -0.168981
# RMSE: 13.734028
# MAE: 13.393912
# MAPE: 0.713128
# 模型的评估结果:
# PersonR: 0.271592
# R2: -21.322714
# Explained Variance: -0.169534
# RMSE: 13.513991
# MAE: 13.155215
# MAPE: 0.702524
# 模型的评估结果:
# PersonR: 0.268126
# R2: -21.896829
# Explained Variance: -0.166474
# RMSE: 13.384683
# MAE: 13.039287
# MAPE: 0.702080
# 模型的评估结果:
# PersonR: 0.401641
# R2: -20.597649
# Explained Variance: 0.039109
# RMSE: 13.037125
# MAE: 12.743811
# MAPE: 0.692038
# 模型的评估结果:
# PersonR: 0.521697
# R2: -20.141747
# Explained Variance: 0.223879
# RMSE: 12.871652
# MAE: 12.633182
# MAPE: 0.693743
# 模型的评估结果:
# PersonR: 0.480141
# R2: -22.057478
# Explained Variance: 0.160668
# RMSE: 12.791577
# MAE: 12.556601
# MAPE: 0.696271
# 模型的评估结果:
# PersonR: 0.418656
# R2: -28.469182
# Explained Variance: 0.011936
# RMSE: 12.694141
# MAE: 12.479517
# MAPE: 0.698555
# 模型的评估结果:
# PersonR: 0.456957
# R2: -29.631988
# Explained Variance: 0.020461
# RMSE: 12.412395
# MAE: 12.212323
# MAPE: 0.700713
# 模型的评估结果:
# PersonR: 0.343488
# R2: -27.761292
# Explained Variance: -0.180460
# RMSE: 12.409838
# MAE: 12.152499
# MAPE: 0.704695
# 模型的评估结果:
# PersonR: 0.297049
# R2: -22.390049
# Explained Variance: -0.170799
# RMSE: 12.089292
# MAE: 11.782841
# MAPE: 0.690748
# 模型的评估结果:
# PersonR: 0.208397
# R2: -20.282858
# Explained Variance: -0.280609
# RMSE: 11.846949
# MAE: 11.484999
# MAPE: 0.681409
# 模型的评估结果:
# PersonR: 0.297603
# R2: -18.196769
# Explained Variance: -0.046031
# RMSE: 11.737529
# MAE: 11.413261
# MAPE: 0.684734
# 模型的评估结果:
# PersonR: 0.418987
# R2: -15.012757
# Explained Variance: 0.135954
# RMSE: 11.414269
# MAE: 11.102043
# MAPE: 0.679190
# 模型的评估结果:
# PersonR: 0.463008
# R2: -12.829233
# Explained Variance: 0.191744
# RMSE: 11.056925
# MAE: 10.728947
# MAPE: 0.664667
# 模型的评估结果:
# PersonR: 0.304432
# R2: -12.267027
# Explained Variance: 0.006226
# RMSE: 10.856485
# MAE: 10.441966
# MAPE: 0.649496
# 模型的评估结果:
# PersonR: 0.245351
# R2: -11.998791
# Explained Variance: -0.101997
# RMSE: 10.556558
# MAE: 10.099174
# MAPE: 0.638893
# 模型的评估结果:
# PersonR: 0.238469
# R2: -11.804264
# Explained Variance: -0.088302
# RMSE: 10.258227
# MAE: 9.812597
# MAPE: 0.627228
# 模型的评估结果:
# PersonR: 0.153365
# R2: -11.906291
# Explained Variance: -0.126216
# RMSE: 10.122922
# MAE: 9.671174
# MAPE: 0.617985
# 模型的评估结果:
# PersonR: 0.263321
# R2: -12.070460
# Explained Variance: -0.013509
# RMSE: 10.088372
# MAE: 9.689345
# MAPE: 0.625338
# 模型的评估结果:
# PersonR: 0.177988
# R2: -11.085906
# Explained Variance: -0.066198
# RMSE: 9.841876
# MAE: 9.397738
# MAPE: 0.609795
# 模型的评估结果:
# PersonR: 0.029610
# R2: -8.928540
# Explained Variance: -0.164791
# RMSE: 9.239986
# MAE: 8.681076
# MAPE: 0.561894
# 模型的评估结果:
# PersonR: -0.152702
# R2: -8.227753
# Explained Variance: -0.273943
# RMSE: 8.985866
# MAE: 8.342565
# MAPE: 0.542442
# 模型的评估结果:
# PersonR: -0.017344
# R2: -7.324080
# Explained Variance: -0.172466
# RMSE: 8.489805
# MAE: 7.869218
# MAPE: 0.515124
# 模型的评估结果:
# PersonR: 0.499206
# R2: -3.454215
# Explained Variance: 0.245755
# RMSE: 7.719500
# MAE: 7.035624
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.753378
# R2: -1.146668
# Explained Variance: 0.475274
# RMSE: 7.251617
# MAE: 6.355642
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.799159
# R2: -0.328162
# Explained Variance: 0.541930
# RMSE: 6.384157
# MAE: 5.316907
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.385071
# R2: -25.334237
# Explained Variance: -0.471709
# RMSE: 20.826500
# MAE: 20.236182
# MAPE: 1.679796
# 模型的评估结果:
# PersonR: -0.530819
# R2: -29.326114
# Explained Variance: -0.567082
# RMSE: 22.869676
# MAE: 22.270951
# MAPE: 1.966529
# 模型的评估结果:
# PersonR: -0.449063
# R2: -30.834032
# Explained Variance: -0.537768
# RMSE: 22.117423
# MAE: 21.576611
# MAPE: 1.977535
# 模型的评估结果:
# PersonR: -0.654530
# R2: -34.575460
# Explained Variance: -1.167228
# RMSE: 23.125583
# MAE: 22.410120
# MAPE: 2.070657
# 模型的评估结果:
# PersonR: -0.622086
# R2: -31.255348
# Explained Variance: -0.911105
# RMSE: 22.382202
# MAE: 21.709014
# MAPE: 2.014530
# 模型的评估结果:
# PersonR: -0.211217
# R2: -31.200616
# Explained Variance: -0.577336
# RMSE: 21.290474
# MAE: 20.762474
# MAPE: 2.013449
# 模型的评估结果:
# PersonR: -0.121811
# R2: -34.328226
# Explained Variance: -0.528859
# RMSE: 20.326046
# MAE: 19.881369
# MAPE: 1.978746
# 模型的评估结果:
# PersonR: 0.141886
# R2: -39.619436
# Explained Variance: -0.235942
# RMSE: 20.743853
# MAE: 20.425825
# MAPE: 2.092638
# 模型的评估结果:
# PersonR: 0.091693
# R2: -45.143156
# Explained Variance: -0.319581
# RMSE: 21.786506
# MAE: 21.472726
# MAPE: 2.255426
# 模型的评估结果:
# PersonR: 0.209917
# R2: -47.809719
# Explained Variance: -0.161342
# RMSE: 22.644886
# MAE: 22.373867
# MAPE: 2.425901
# 模型的评估结果:
# PersonR: -0.077100
# R2: -53.399638
# Explained Variance: -0.647931
# RMSE: 21.914430
# MAE: 21.579950
# MAPE: 2.321033
# 模型的评估结果:
# PersonR: -0.094656
# R2: -49.966654
# Explained Variance: -0.617796
# RMSE: 20.697342
# MAE: 20.366203
# MAPE: 2.250902
# 模型的评估结果:
# PersonR: -0.186624
# R2: -48.896616
# Explained Variance: -0.669471
# RMSE: 21.187429
# MAE: 20.829963
# MAPE: 2.355940
# 模型的评估结果:
# PersonR: -0.113267
# R2: -45.334106
# Explained Variance: -0.708096
# RMSE: 21.197515
# MAE: 20.803125
# MAPE: 2.414221
# 模型的评估结果:
# PersonR: -0.039558
# R2: -39.390543
# Explained Variance: -0.548819
# RMSE: 19.768553
# MAE: 19.385825
# MAPE: 2.291823
# 模型的评估结果:
# PersonR: -0.150811
# R2: -41.225620
# Explained Variance: -0.705169
# RMSE: 18.927498
# MAE: 18.541391
# MAPE: 2.301202
# 模型的评估结果:
# PersonR: -0.506326
# R2: -46.584397
# Explained Variance: -1.379083
# RMSE: 20.354053
# MAE: 19.838707
# MAPE: 2.717333
# 模型的评估结果:
# PersonR: -0.538342
# R2: -36.869585
# Explained Variance: -1.506448
# RMSE: 18.821486
# MAE: 18.187962
# MAPE: 3.045803
# 模型的评估结果:
# PersonR: -0.354630
# R2: -32.121486
# Explained Variance: -0.957751
# RMSE: 18.278612
# MAE: 17.730176
# MAPE: 3.447573
# 模型的评估结果:
# PersonR: -0.398791
# R2: -25.589492
# Explained Variance: -0.803803
# RMSE: 17.331567
# MAE: 16.733366
# MAPE: 3.530590
# 模型的评估结果:
# PersonR: -0.492688
# R2: -24.627703
# Explained Variance: -1.055613
# RMSE: 17.641266
# MAE: 16.918971
# MAPE: 3.487512
# 模型的评估结果:
# PersonR: -0.233042
# R2: -17.983727
# Explained Variance: -0.429187
# RMSE: 15.729799
# MAE: 15.126107
# MAPE: 3.919143
# 模型的评估结果:
# PersonR: 0.079001
# R2: -17.731672
# Explained Variance: -0.249763
# RMSE: 16.715538
# MAE: 16.148289
# MAPE: 5.002105
# 模型的评估结果:
# PersonR: -0.091900
# R2: -16.981636
# Explained Variance: -0.223013
# RMSE: 17.204835
# MAE: 16.609443
# MAPE: 5.188962
# 模型的评估结果:
# PersonR: -0.404949
# R2: -15.446424
# Explained Variance: -0.657352
# RMSE: 17.478595
# MAE: 16.574531
# MAPE: 4.817428
# 模型的评估结果:
# PersonR: -0.399016
# R2: -13.660920
# Explained Variance: -0.665591
# RMSE: 17.146254
# MAE: 16.142927
# MAPE: 4.802639
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# 模型的评估结果:
# PersonR: -0.223209
# R2: -13.007338
# Explained Variance: -0.516335
# RMSE: 17.222425
# MAE: 16.263543
# MAPE: 5.534087
# 模型的评估结果:
# PersonR: -0.469502
# R2: -15.154810
# Explained Variance: -0.974405
# RMSE: 18.656874
# MAE: 17.479631
# MAPE: 5.918128
# 模型的评估结果:
# PersonR: -0.293005
# R2: -14.744389
# Explained Variance: -1.103785
# RMSE: 18.531939
# MAE: 17.249430
# MAPE: 6.002049
# 模型的评估结果:
# PersonR: -0.183850
# R2: -11.176567
# Explained Variance: -0.607517
# RMSE: 16.457342
# MAE: 15.332580
# MAPE: 5.727981
# 模型的评估结果:
# PersonR: -0.490655
# R2: -11.424828
# Explained Variance: -1.077448
# RMSE: 16.683708
# MAE: 15.225185
# MAPE: 5.388167
# 模型的评估结果:
# PersonR: -0.709788
# R2: -13.007887
# Explained Variance: -1.172067
# RMSE: 17.986514
# MAE: 16.533312
# MAPE: 5.937569
# 模型的评估结果:
# PersonR: -0.627177
# R2: -10.121224
# Explained Variance: -0.892999
# RMSE: 16.244008
# MAE: 14.797079
# MAPE: 5.502147
# 模型的评估结果:
# PersonR: -0.501871
# R2: -10.193861
# Explained Variance: -1.013024
# RMSE: 16.391097
# MAE: 14.844282
# MAPE: 5.868900
# 模型的评估结果:
# PersonR: -0.480235
# R2: -8.610258
# Explained Variance: -0.833992
# RMSE: 15.127844
# MAE: 13.608024
# MAPE: 5.475350
# 模型的评估结果:
# PersonR: -0.522215
# R2: -7.759640
# Explained Variance: -0.731065
# RMSE: 14.265633
# MAE: 12.778550
# MAPE: 4.806209
# 模型的评估结果:
# PersonR: -0.508695
# R2: -6.438353
# Explained Variance: -0.688423
# RMSE: 12.053979
# MAE: 10.597986
# MAPE: 4.195643
# 模型的评估结果:
# PersonR: -0.502701
# R2: -8.592051
# Explained Variance: -1.218778
# RMSE: 13.983418
# MAE: 12.259923
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.323523
# R2: -6.661409
# Explained Variance: -1.138734
# RMSE: 12.463248
# MAE: 10.581608
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.166409
# R2: -5.332593
# Explained Variance: -1.118904
# RMSE: 10.060947
# MAE: 8.259776
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.255450
# R2: -22.015442
# Explained Variance: -0.129536
# RMSE: 21.600290
# MAE: 21.063581
# MAPE: 2.316040
# 模型的评估结果:
# PersonR: 0.225880
# R2: -20.277226
# Explained Variance: -0.227416
# RMSE: 22.040569
# MAE: 21.395401
# MAPE: 2.554177
# 模型的评估结果:
# PersonR: 0.375338
# R2: -19.672615
# Explained Variance: 0.035147
# RMSE: 21.661675
# MAE: 21.150127
# MAPE: 2.820897
# 模型的评估结果:
# PersonR: 0.527122
# R2: -22.183718
# Explained Variance: 0.275746
# RMSE: 22.538674
# MAE: 22.183830
# MAPE: 3.189836
# 模型的评估结果:
# PersonR: 0.472187
# R2: -21.347545
# Explained Variance: 0.190588
# RMSE: 21.980951
# MAE: 21.579212
# MAPE: 3.126833
# 模型的评估结果:
# PersonR: 0.481731
# R2: -21.629080
# Explained Variance: 0.207460
# RMSE: 21.522535
# MAE: 21.142283
# MAPE: 3.202080
# 模型的评估结果:
# PersonR: 0.520913
# R2: -22.251476
# Explained Variance: 0.254069
# RMSE: 21.081518
# MAE: 20.740603
# MAPE: 3.530276
# 模型的评估结果:
# PersonR: 0.430585
# R2: -22.988547
# Explained Variance: 0.006740
# RMSE: 20.326416
# MAE: 19.901154
# MAPE: 3.577765
# 模型的评估结果:
# PersonR: 0.480224
# R2: -24.601757
# Explained Variance: 0.067981
# RMSE: 20.442683
# MAE: 20.067131
# MAPE: 3.738383
# 模型的评估结果:
# PersonR: 0.446115
# R2: -25.746614
# Explained Variance: -0.009942
# RMSE: 20.820786
# MAE: 20.423910
# MAPE: 3.745870
# 模型的评估结果:
# PersonR: 0.473101
# R2: -24.262272
# Explained Variance: 0.134769
# RMSE: 20.255782
# MAE: 19.905881
# MAPE: 3.765242
# 模型的评估结果:
# PersonR: 0.440946
# R2: -23.695206
# Explained Variance: 0.087924
# RMSE: 19.942704
# MAE: 19.570964
# MAPE: 3.746553
# 模型的评估结果:
# PersonR: 0.128569
# R2: -26.342522
# Explained Variance: -0.642231
# RMSE: 19.497086
# MAE: 18.902508
# MAPE: 3.533618
# 模型的评估结果:
# PersonR: 0.368504
# R2: -23.483596
# Explained Variance: -0.509346
# RMSE: 19.371142
# MAE: 18.764556
# MAPE: 3.792108
# 模型的评估结果:
# PersonR: 0.441782
# R2: -19.361404
# Explained Variance: -0.147468
# RMSE: 18.270128
# MAE: 17.747857
# MAPE: 3.934578
# 模型的评估结果:
# PersonR: 0.449557
# R2: -18.030240
# Explained Variance: -0.099399
# RMSE: 17.872262
# MAE: 17.348332
# MAPE: 4.071105
# 模型的评估结果:
# PersonR: 0.480198
# R2: -15.052864
# Explained Variance: 0.053210
# RMSE: 17.114743
# MAE: 16.602364
# MAPE: 4.029214
# 模型的评估结果:
# PersonR: 0.270942
# R2: -12.937571
# Explained Variance: -0.565128
# RMSE: 16.988192
# MAE: 16.005946
# MAPE: 3.897074
# 模型的评估结果:
# PersonR: 0.339396
# R2: -12.444839
# Explained Variance: -0.521314
# RMSE: 17.455539
# MAE: 16.438334
# MAPE: 3.919226
# 模型的评估结果:
# PersonR: 0.403064
# R2: -10.992565
# Explained Variance: -0.810576
# RMSE: 15.873538
# MAE: 14.649956
# MAPE: 3.752596
# 模型的评估结果:
# PersonR: 0.292427
# R2: -7.185251
# Explained Variance: -0.739081
# RMSE: 14.173942
# MAE: 12.680684
# MAPE: 3.336438
# 模型的评估结果:
# PersonR: 0.411104
# R2: -4.710067
# Explained Variance: -0.360060
# RMSE: 13.012124
# MAE: 11.621991
# MAPE: 3.106826
# 模型的评估结果:
# PersonR: 0.551011
# R2: -4.922464
# Explained Variance: -0.073735
# RMSE: 13.851225
# MAE: 12.532881
# MAPE: 3.487417
# 模型的评估结果:
# PersonR: 0.448043
# R2: -5.036311
# Explained Variance: -0.107154
# RMSE: 14.360941
# MAE: 13.209852
# MAPE: 3.455179
# 模型的评估结果:
# PersonR: 0.506765
# R2: -4.036866
# Explained Variance: -0.156876
# RMSE: 13.309598
# MAE: 12.183452
# MAPE: 3.620951
# 模型的评估结果:
# PersonR: 0.494934
# R2: -2.899889
# Explained Variance: -0.148705
# RMSE: 12.143531
# MAE: 10.691984
# MAPE: 3.026186
# 模型的评估结果:
# PersonR: 0.615286
# R2: -2.858928
# Explained Variance: -0.016834
# RMSE: 12.452705
# MAE: 10.801336
# MAPE: 2.866041
# 模型的评估结果:
# PersonR: 0.646436
# R2: -2.719750
# Explained Variance: 0.288867
# RMSE: 12.409106
# MAE: 11.160074
# MAPE: 3.487521
# 模型的评估结果:
# PersonR: 0.570007
# R2: -1.894167
# Explained Variance: -0.030225
# RMSE: 10.809079
# MAE: 9.265633
# MAPE: 3.072351
# 模型的评估结果:
# PersonR: 0.588775
# R2: -1.637401
# Explained Variance: -0.045910
# RMSE: 10.218523
# MAE: 8.661177
# MAPE: 2.746214
# 模型的评估结果:
# PersonR: 0.585069
# R2: -1.855479
# Explained Variance: -0.106155
# RMSE: 10.462842
# MAE: 8.677299
# MAPE: 2.907613
# 模型的评估结果:
# PersonR: 0.507566
# R2: -2.240529
# Explained Variance: -0.181990
# RMSE: 11.344413
# MAE: 9.398930
# MAPE: 2.720310
# 模型的评估结果:
# PersonR: 0.534567
# R2: -1.266541
# Explained Variance: -0.039415
# RMSE: 9.464447
# MAE: 7.903779
# MAPE: 2.716654
# 模型的评估结果:
# PersonR: 0.602159
# R2: -1.180255
# Explained Variance: 0.027672
# RMSE: 9.443972
# MAE: 8.010226
# MAPE: 2.437939
# 模型的评估结果:
# PersonR: 0.584230
# R2: -0.744884
# Explained Variance: -0.045282
# RMSE: 8.372186
# MAE: 7.037556
# MAPE: 2.036904
# 模型的评估结果:
# PersonR: 0.517729
# R2: -0.518308
# Explained Variance: 0.026326
# RMSE: 7.666674
# MAE: 6.358332
# MAPE: 2.003485
# 模型的评估结果:
# PersonR: 0.362794
# R2: -0.432824
# Explained Variance: -0.237469
# RMSE: 7.451892
# MAE: 6.245535
# MAPE: 1.853845
# 模型的评估结果:
# PersonR: 0.190407
# R2: -1.263213
# Explained Variance: -0.976693
# RMSE: 8.205894
# MAE: 7.167474
# MAPE: 2.515738
# 模型的评估结果:
# PersonR: 0.418695
# R2: -0.704199
# Explained Variance: -0.097913
# RMSE: 7.517817
# MAE: 6.208811
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.467142
# R2: -0.192339
# Explained Variance: -0.091611
# RMSE: 5.798116
# MAE: 4.273182
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.089681
# R2: -95.738031
# Explained Variance: -0.773676
# RMSE: 25.538287
# MAE: 25.303084
# MAPE: 1.857720
# 模型的评估结果:
# PersonR: -0.371951
# R2: -89.021184
# Explained Variance: -1.640759
# RMSE: 25.756383
# MAE: 25.375791
# MAPE: 1.893487
# 模型的评估结果:
# PersonR: -0.345237
# R2: -74.986978
# Explained Variance: -1.149629
# RMSE: 25.601701
# MAE: 25.236975
# MAPE: 1.927391
# 模型的评估结果:
# PersonR: -0.313932
# R2: -74.033055
# Explained Variance: -0.797977
# RMSE: 26.535211
# MAE: 26.215359
# MAPE: 2.073369
# 模型的评估结果:
# PersonR: -0.045323
# R2: -62.883593
# Explained Variance: -0.458024
# RMSE: 25.642127
# MAE: 25.347821
# MAPE: 2.079915
# 模型的评估结果:
# PersonR: 0.156406
# R2: -48.951799
# Explained Variance: -0.382469
# RMSE: 24.223469
# MAE: 23.885912
# MAPE: 2.057946
# 模型的评估结果:
# PersonR: -0.096463
# R2: -45.007879
# Explained Variance: -0.580171
# RMSE: 24.155946
# MAE: 23.737496
# MAPE: 2.101354
# 模型的评估结果:
# PersonR: 0.188856
# R2: -33.641215
# Explained Variance: -0.315685
# RMSE: 21.793514
# MAE: 21.375646
# MAPE: 1.999009
# 模型的评估结果:
# PersonR: 0.078457
# R2: -33.856969
# Explained Variance: -0.497501
# RMSE: 22.441237
# MAE: 21.953893
# MAPE: 2.096992
# 模型的评估结果:
# PersonR: 0.048865
# R2: -35.317549
# Explained Variance: -0.269390
# RMSE: 22.732652
# MAE: 22.331837
# MAPE: 2.188985
# 模型的评估结果:
# PersonR: 0.098747
# R2: -34.438867
# Explained Variance: -0.249974
# RMSE: 21.731883
# MAE: 21.345187
# MAPE: 2.132486
# 模型的评估结果:
# PersonR: 0.101252
# R2: -36.041925
# Explained Variance: -0.523005
# RMSE: 22.210816
# MAE: 21.749417
# MAPE: 2.216287
# 模型的评估结果:
# PersonR: 0.269033
# R2: -31.091441
# Explained Variance: -0.244531
# RMSE: 20.545756
# MAE: 20.143426
# MAPE: 2.104718
# 模型的评估结果:
# PersonR: 0.098965
# R2: -31.270372
# Explained Variance: -0.373554
# RMSE: 20.382387
# MAE: 19.943893
# MAPE: 2.124033
# 模型的评估结果:
# PersonR: 0.009017
# R2: -26.689171
# Explained Variance: -0.289026
# RMSE: 19.318143
# MAE: 18.863121
# MAPE: 2.027478
# 模型的评估结果:
# PersonR: 0.240761
# R2: -30.063287
# Explained Variance: -0.082181
# RMSE: 20.075595
# MAE: 19.722799
# MAPE: 2.196363
# 模型的评估结果:
# PersonR: 0.326274
# R2: -27.660599
# Explained Variance: -0.171043
# RMSE: 19.153325
# MAE: 18.757952
# MAPE: 2.150219
# 模型的评估结果:
# PersonR: 0.271100
# R2: -20.815421
# Explained Variance: -0.713360
# RMSE: 16.745305
# MAE: 16.074281
# MAPE: 1.879179
# 模型的评估结果:
# PersonR: 0.116340
# R2: -22.859822
# Explained Variance: -1.131031
# RMSE: 17.698531
# MAE: 16.889679
# MAPE: 2.001978
# 模型的评估结果:
# PersonR: 0.247999
# R2: -17.188303
# Explained Variance: -0.834454
# RMSE: 15.147787
# MAE: 14.363593
# MAPE: 1.769637
# 模型的评估结果:
# PersonR: 0.091454
# R2: -13.202909
# Explained Variance: -0.729229
# RMSE: 13.296491
# MAE: 12.464140
# MAPE: 1.512366
# 模型的评估结果:
# PersonR: 0.247806
# R2: -8.472999
# Explained Variance: -0.273291
# RMSE: 10.796677
# MAE: 10.044899
# MAPE: 1.216812
# 模型的评估结果:
# PersonR: 0.265666
# R2: -12.494867
# Explained Variance: -0.808453
# RMSE: 12.085829
# MAE: 11.371811
# MAPE: 1.453187
# 模型的评估结果:
# PersonR: 0.239242
# R2: -10.050635
# Explained Variance: -0.367254
# RMSE: 10.759053
# MAE: 10.071495
# MAPE: 1.265140
# 模型的评估结果:
# PersonR: 0.244690
# R2: -10.971003
# Explained Variance: -0.360972
# RMSE: 10.798365
# MAE: 10.170169
# MAPE: 1.296269
# 模型的评估结果:
# PersonR: 0.352687
# R2: -10.310408
# Explained Variance: -0.163621
# RMSE: 9.739328
# MAE: 9.224740
# MAPE: 1.223193
# 模型的评估结果:
# PersonR: 0.045404
# R2: -7.425912
# Explained Variance: -0.475691
# RMSE: 7.871422
# MAE: 7.203105
# MAPE: 0.942892
# 模型的评估结果:
# PersonR: 0.135831
# R2: -12.619331
# Explained Variance: -0.175054
# RMSE: 9.966012
# MAE: 9.526390
# MAPE: 1.331349
# 模型的评估结果:
# PersonR: 0.121575
# R2: -9.814964
# Explained Variance: -0.234217
# RMSE: 9.095013
# MAE: 8.560330
# MAPE: 1.216540
# 模型的评估结果:
# PersonR: 0.356986
# R2: -4.657394
# Explained Variance: -0.033421
# RMSE: 6.604957
# MAE: 5.971307
# MAPE: 0.868993
# 模型的评估结果:
# PersonR: 0.422544
# R2: -6.964828
# Explained Variance: 0.140741
# RMSE: 7.853054
# MAE: 7.417368
# MAPE: 1.170987
# 模型的评估结果:
# PersonR: 0.145361
# R2: -17.092225
# Explained Variance: -0.096058
# RMSE: 11.507147
# MAE: 11.153141
# MAPE: 1.911270
# 模型的评估结果:
# PersonR: 0.346991
# R2: -12.234575
# Explained Variance: -0.015940
# RMSE: 9.250804
# MAE: 8.888651
# MAPE: 1.626753
# 模型的评估结果:
# PersonR: -0.013845
# R2: -8.600690
# Explained Variance: -0.428058
# RMSE: 7.830608
# MAE: 7.224790
# MAPE: 1.306782
# 模型的评估结果:
# PersonR: -0.238412
# R2: -6.936189
# Explained Variance: -0.748620
# RMSE: 6.652198
# MAE: 5.891533
# MAPE: 1.015350
# 模型的评估结果:
# PersonR: -0.387080
# R2: -11.607622
# Explained Variance: -0.926325
# RMSE: 8.011910
# MAE: 7.374481
# MAPE: 1.413190
# 模型的评估结果:
# PersonR: -0.125781
# R2: -10.240358
# Explained Variance: -0.487172
# RMSE: 7.934228
# MAE: 7.390739
# MAPE: 1.546387
# 模型的评估结果:
# PersonR: 0.017876
# R2: -10.183122
# Explained Variance: -0.450435
# RMSE: 7.364726
# MAE: 6.870549
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.199768
# R2: -7.389383
# Explained Variance: -0.712924
# RMSE: 7.069801
# MAE: 6.319251
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.178838
# R2: -3.203109
# Explained Variance: -0.299799
# RMSE: 5.387841
# MAE: 4.610802
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.176795
# R2: -66.754072
# Explained Variance: -0.489487
# RMSE: 35.517035
# MAE: 35.124467
# MAPE: 1.558853
# 模型的评估结果:
# PersonR: -0.235026
# R2: -71.265043
# Explained Variance: -0.422451
# RMSE: 36.179393
# MAE: 35.821550
# MAPE: 1.604698
# 模型的评估结果:
# PersonR: -0.168078
# R2: -64.254099
# Explained Variance: -0.348814
# RMSE: 34.907323
# MAE: 34.544669
# MAPE: 1.562409
# 模型的评估结果:
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# PersonR: -0.120380
# R2: -64.521064
# Explained Variance: -0.151464
# RMSE: 35.700213
# MAE: 35.385125
# MAPE: 1.620841
# 模型的评估结果:
# PersonR: -0.124152
# R2: -67.021363
# Explained Variance: -0.146159
# RMSE: 35.876485
# MAE: 35.572942
# MAPE: 1.650783
# 模型的评估结果:
# PersonR: -0.098043
# R2: -67.657580
# Explained Variance: -0.342721
# RMSE: 35.456445
# MAE: 35.108026
# MAPE: 1.648015
# 模型的评估结果:
# PersonR: -0.084641
# R2: -69.542962
# Explained Variance: -0.330661
# RMSE: 34.971070
# MAE: 34.639668
# MAPE: 1.636056
# 模型的评估结果:
# PersonR: -0.128801
# R2: -69.956013
# Explained Variance: -0.586411
# RMSE: 34.315240
# MAE: 33.929467
# MAPE: 1.614872
# 模型的评估结果:
# PersonR: -0.165432
# R2: -77.537960
# Explained Variance: -0.796363
# RMSE: 35.175995
# MAE: 34.771386
# MAPE: 1.673369
# 模型的评估结果:
# PersonR: -0.277277
# R2: -84.305492
# Explained Variance: -0.668432
# RMSE: 34.946830
# MAE: 34.603392
# MAPE: 1.688884
# 模型的评估结果:
# PersonR: 0.044456
# R2: -77.748294
# Explained Variance: -0.097971
# RMSE: 33.570544
# MAE: 33.335689
# MAPE: 1.645123
# 模型的评估结果:
# PersonR: 0.012292
# R2: -83.508793
# Explained Variance: -0.172007
# RMSE: 33.071957
# MAE: 32.841828
# MAPE: 1.635967
# 模型的评估结果:
# PersonR: -0.312255
# R2: -95.529050
# Explained Variance: -0.908054
# RMSE: 32.847708
# MAE: 32.521443
# MAPE: 1.641090
# 模型的评估结果:
# PersonR: -0.081683
# R2: -109.988514
# Explained Variance: -0.735374
# RMSE: 32.912269
# MAE: 32.653954
# MAPE: 1.665174
# 模型的评估结果:
# PersonR: -0.092743
# R2: -113.843525
# Explained Variance: -0.621111
# RMSE: 31.568903
# MAE: 31.345300
# MAPE: 1.618792
# 模型的评估结果:
# PersonR: 0.321586
# R2: -119.952175
# Explained Variance: -0.087736
# RMSE: 32.195559
# MAE: 32.050463
# MAPE: 1.683089
# 模型的评估结果:
# PersonR: 0.001778
# R2: -110.504510
# Explained Variance: -0.318607
# RMSE: 31.912261
# MAE: 31.723009
# MAPE: 1.677929
# 模型的评估结果:
# PersonR: 0.305687
# R2: -110.194587
# Explained Variance: -0.437897
# RMSE: 30.722469
# MAE: 30.523181
# MAPE: 1.636608
# 模型的评估结果:
# PersonR: 0.177869
# R2: -136.795673
# Explained Variance: -0.511376
# RMSE: 31.465770
# MAE: 31.292732
# MAPE: 1.688068
# 模型的评估结果:
# PersonR: 0.122953
# R2: -159.035514
# Explained Variance: -1.471120
# RMSE: 29.802070
# MAE: 29.571086
# MAPE: 1.606333
# 模型的评估结果:
# PersonR: 0.013051
# R2: -164.332267
# Explained Variance: -2.623954
# RMSE: 27.524616
# MAE: 27.221286
# MAPE: 1.485129
# 模型的评估结果:
# PersonR: -0.059787
# R2: -160.774772
# Explained Variance: -2.931902
# RMSE: 24.946115
# MAE: 24.641095
# MAPE: 1.363697
# 模型的评估结果:
# PersonR: 0.002524
# R2: -132.606600
# Explained Variance: -2.499883
# RMSE: 25.264586
# MAE: 24.931481
# MAPE: 1.414147
# 模型的评估结果:
# PersonR: -0.009222
# R2: -81.775020
# Explained Variance: -2.636705
# RMSE: 23.838170
# MAE: 23.308626
# MAPE: 1.341476
# 模型的评估结果:
# PersonR: -0.109050
# R2: -77.527054
# Explained Variance: -3.456882
# RMSE: 25.680548
# MAE: 24.941141
# MAPE: 1.454364
# 模型的评估结果:
# PersonR: 0.009157
# R2: -63.042297
# Explained Variance: -2.832139
# RMSE: 23.835210
# MAE: 23.111089
# MAPE: 1.358754
# 模型的评估结果:
# PersonR: 0.078331
# R2: -55.581066
# Explained Variance: -3.335555
# RMSE: 23.265533
# MAE: 22.356404
# MAPE: 1.328095
# 模型的评估结果:
# PersonR: 0.033698
# R2: -61.359780
# Explained Variance: -3.581459
# RMSE: 25.909684
# MAE: 24.939762
# MAPE: 1.496953
# 模型的评估结果:
# PersonR: 0.093889
# R2: -52.962157
# Explained Variance: -3.277890
# RMSE: 24.777852
# MAE: 23.775433
# MAPE: 1.442629
# 模型的评估结果:
# PersonR: 0.235716
# R2: -45.066803
# Explained Variance: -2.297151
# RMSE: 23.267358
# MAE: 22.419241
# MAPE: 1.375185
# 模型的评估结果:
# PersonR: 0.272375
# R2: -46.009864
# Explained Variance: -2.022913
# RMSE: 23.403230
# MAE: 22.638270
# MAPE: 1.401382
# 模型的评估结果:
# PersonR: 0.311719
# R2: -57.728653
# Explained Variance: -1.760524
# RMSE: 26.011948
# MAE: 25.393248
# MAPE: 1.584558
# 模型的评估结果:
# PersonR: 0.215555
# R2: -49.456533
# Explained Variance: -2.031246
# RMSE: 23.970722
# MAE: 23.239533
# MAPE: 1.438836
# 模型的评估结果:
# PersonR: 0.170560
# R2: -41.001948
# Explained Variance: -2.145937
# RMSE: 22.328063
# MAE: 21.475607
# MAPE: 1.338694
# 模型的评估结果:
# PersonR: 0.202583
# R2: -32.917631
# Explained Variance: -1.948575
# RMSE: 20.690391
# MAE: 19.770604
# MAPE: 1.253618
# 模型的评估结果:
# PersonR: 0.309207
# R2: -37.759404
# Explained Variance: -1.003091
# RMSE: 22.143731
# MAE: 21.563945
# MAPE: 1.396804
# 模型的评估结果:
# PersonR: 0.382148
# R2: -32.139748
# Explained Variance: -0.688271
# RMSE: 20.147383
# MAE: 19.627481
# MAPE: 1.284071
# 模型的评估结果:
# PersonR: 0.245955
# R2: -23.433950
# Explained Variance: -1.161520
# RMSE: 19.782086
# MAE: 18.886829
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.030557
# R2: -12.504852
# Explained Variance: -0.427024
# RMSE: 18.888511
# MAE: 17.862706
# MAPE: nan
# 模型的评估结果:
# PersonR: -0.034368
# R2: -6.638750
# Explained Variance: -0.291831
# RMSE: 16.275308
# MAE: 14.835409
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.136331
# R2: -113.891364
# Explained Variance: -0.492295
# RMSE: 33.825246
# MAE: 33.604855
# MAPE: 1.561670
# 模型的评估结果:
# PersonR: 0.121456
# R2: -105.096505
# Explained Variance: -0.470058
# RMSE: 33.675468
# MAE: 33.441353
# MAPE: 1.567318
# 模型的评估结果:
# PersonR: -0.069890
# R2: -93.890173
# Explained Variance: -0.404440
# RMSE: 33.176986
# MAE: 32.930550
# MAPE: 1.558409
# 模型的评估结果:
# PersonR: 0.133688
# R2: -93.574586
# Explained Variance: -0.022468
# RMSE: 34.234427
# MAE: 34.048866
# MAPE: 1.637719
# 模型的评估结果:
# PersonR: 0.075021
# R2: -96.084541
# Explained Variance: -0.280599
# RMSE: 34.894144
# MAE: 34.663244
# MAPE: 1.685783
# 模型的评估结果:
# PersonR: 0.197616
# R2: -97.528356
# Explained Variance: -0.236249
# RMSE: 35.549974
# MAE: 35.326245
# MAPE: 1.726275
# 模型的评估结果:
# PersonR: 0.381063
# R2: -94.228936
# Explained Variance: -0.061618
# RMSE: 34.298472
# MAE: 34.106755
# MAPE: 1.689017
# 模型的评估结果:
# PersonR: 0.118496
# R2: -86.252514
# Explained Variance: -0.653183
# RMSE: 32.860603
# MAE: 32.547808
# MAPE: 1.627186
# 模型的评估结果:
# PersonR: -0.140316
# R2: -97.984584
# Explained Variance: -1.324521
# RMSE: 33.290954
# MAE: 32.897735
# MAPE: 1.663677
# 模型的评估结果:
# ...
# Explained Variance: 0.707410
# RMSE: 2.169879
# MAE: 1.696505
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.904426
# R2: 0.814706
# Explained Variance: 0.817417
# RMSE: 2.212503
# MAE: 1.675649
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.925914
# R2: 0.848964
# Explained Variance: 0.857305
# RMSE: 2.288538
# MAE: 1.632629
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.826981
# R2: 0.484961
# Explained Variance: 0.594145
# RMSE: 2.264736
# MAE: 1.972106
# MAPE: 0.091578
# 模型的评估结果:
# PersonR: 0.835110
# R2: 0.510488
# Explained Variance: 0.590382
# RMSE: 2.287415
# MAE: 1.858184
# MAPE: 0.086686
# 模型的评估结果:
# PersonR: 0.876431
# R2: 0.649813
# Explained Variance: 0.727223
# RMSE: 2.015469
# MAE: 1.535885
# MAPE: 0.072243
# 模型的评估结果:
# PersonR: 0.874693
# R2: 0.674379
# Explained Variance: 0.703564
# RMSE: 2.008780
# MAE: 1.651845
# MAPE: 0.078905
# 模型的评估结果:
# PersonR: 0.870512
# R2: 0.688381
# Explained Variance: 0.722819
# RMSE: 1.976922
# MAE: 1.714017
# MAPE: 0.083057
# 模型的评估结果:
# PersonR: 0.847684
# R2: 0.642251
# Explained Variance: 0.669522
# RMSE: 2.142140
# MAE: 1.877375
# MAPE: 0.091730
# 模型的评估结果:
# PersonR: 0.850745
# R2: 0.637239
# Explained Variance: 0.687379
# RMSE: 2.116902
# MAE: 1.781186
# MAPE: 0.088279
# 模型的评估结果:
# PersonR: 0.836963
# R2: 0.593811
# Explained Variance: 0.642738
# RMSE: 2.242078
# MAE: 1.926251
# MAPE: 0.095484
# 模型的评估结果:
# PersonR: 0.880244
# R2: 0.658935
# Explained Variance: 0.717418
# RMSE: 1.954164
# MAE: 1.624987
# MAPE: 0.082422
# 模型的评估结果:
# PersonR: 0.872205
# R2: 0.633236
# Explained Variance: 0.692968
# RMSE: 2.017225
# MAE: 1.700091
# MAPE: 0.087731
# 模型的评估结果:
# PersonR: 0.873277
# R2: 0.642273
# Explained Variance: 0.702023
# RMSE: 1.983654
# MAE: 1.613865
# MAPE: 0.085754
# 模型的评估结果:
# PersonR: 0.807635
# R2: 0.498069
# Explained Variance: 0.551455
# RMSE: 2.226448
# MAE: 1.916434
# MAPE: 0.102188
# 模型的评估结果:
# PersonR: 0.734605
# R2: 0.372529
# Explained Variance: 0.393402
# RMSE: 2.335223
# MAE: 1.872523
# MAPE: 0.099968
# 模型的评估结果:
# PersonR: 0.814425
# R2: 0.507168
# Explained Variance: 0.542247
# RMSE: 1.959432
# MAE: 1.657388
# MAPE: 0.088922
# 模型的评估结果:
# PersonR: 0.816272
# R2: 0.527885
# Explained Variance: 0.550297
# RMSE: 1.930376
# MAE: 1.610231
# MAPE: 0.086733
# 模型的评估结果:
# PersonR: 0.846579
# R2: 0.582882
# Explained Variance: 0.595869
# RMSE: 1.847309
# MAE: 1.578933
# MAPE: 0.087099
# 模型的评估结果:
# PersonR: 0.806289
# R2: 0.464095
# Explained Variance: 0.480867
# RMSE: 2.047691
# MAE: 1.745567
# MAPE: 0.098014
# 模型的评估结果:
# PersonR: 0.793879
# R2: 0.481328
# Explained Variance: 0.490625
# RMSE: 2.020342
# MAE: 1.680913
# MAPE: 0.095207
# 模型的评估结果:
# PersonR: 0.867793
# R2: 0.677676
# Explained Variance: 0.680929
# RMSE: 1.589316
# MAE: 1.295893
# MAPE: 0.073630
# 模型的评估结果:
# PersonR: 0.870907
# R2: 0.641280
# Explained Variance: 0.654270
# RMSE: 1.595496
# MAE: 1.370507
# MAPE: 0.076352
# 模型的评估结果:
# PersonR: 0.852405
# R2: 0.483493
# Explained Variance: 0.489863
# RMSE: 1.680574
# MAE: 1.351069
# MAPE: 0.075858
# 模型的评估结果:
# PersonR: 0.712045
# R2: 0.239383
# Explained Variance: 0.247709
# RMSE: 1.955919
# MAE: 1.546390
# MAPE: 0.092160
# 模型的评估结果:
# PersonR: 0.730844
# R2: 0.220229
# Explained Variance: 0.231597
# RMSE: 2.043363
# MAE: 1.721430
# MAPE: 0.100884
# 模型的评估结果:
# PersonR: 0.830508
# R2: 0.546630
# Explained Variance: 0.548287
# RMSE: 1.683107
# MAE: 1.378104
# MAPE: 0.081309
# 模型的评估结果:
# PersonR: 0.829340
# R2: 0.571607
# Explained Variance: 0.572011
# RMSE: 1.680788
# MAE: 1.442711
# MAPE: 0.088270
# 模型的评估结果:
# PersonR: 0.805943
# R2: 0.529337
# Explained Variance: 0.529460
# RMSE: 1.837883
# MAE: 1.514605
# MAPE: 0.091073
# 模型的评估结果:
# PersonR: 0.813618
# R2: 0.539322
# Explained Variance: 0.545398
# RMSE: 1.936038
# MAE: 1.552531
# MAPE: 0.098026
# 模型的评估结果:
# PersonR: 0.841120
# R2: 0.622660
# Explained Variance: 0.626585
# RMSE: 1.826424
# MAE: 1.487857
# MAPE: 0.092530
# 模型的评估结果:
# PersonR: 0.835016
# R2: 0.619049
# Explained Variance: 0.619050
# RMSE: 1.839658
# MAE: 1.534954
# MAPE: 0.097122
# 模型的评估结果:
# PersonR: 0.808215
# R2: 0.564745
# Explained Variance: 0.568995
# RMSE: 1.931713
# MAE: 1.486420
# MAPE: 0.095761
# 模型的评估结果:
# PersonR: 0.762271
# R2: 0.466558
# Explained Variance: 0.467809
# RMSE: 2.093816
# MAE: 1.628547
# MAPE: 0.108828
# 模型的评估结果:
# PersonR: 0.722886
# R2: 0.425632
# Explained Variance: 0.425632
# RMSE: 2.135503
# MAE: 1.757089
# MAPE: 0.120940
# 模型的评估结果:
# PersonR: 0.744457
# R2: 0.467309
# Explained Variance: 0.478503
# RMSE: 2.036636
# MAE: 1.680124
# MAPE: 0.109909
# 模型的评估结果:
# PersonR: 0.783506
# R2: 0.508363
# Explained Variance: 0.527906
# RMSE: 1.985001
# MAE: 1.597765
# MAPE: 0.104302
# 模型的评估结果:
# PersonR: 0.785086
# R2: 0.553685
# Explained Variance: 0.556684
# RMSE: 1.959067
# MAE: 1.541333
# MAPE: 0.106213
# 模型的评估结果:
# PersonR: 0.733246
# R2: 0.445931
# Explained Variance: 0.446004
# RMSE: 2.201882
# MAE: 1.669191
# MAPE: 0.119711
# 模型的评估结果:
# PersonR: 0.655974
# R2: 0.326834
# Explained Variance: 0.327826
# RMSE: 2.414297
# MAE: 1.778843
# MAPE: 0.124268
# 模型的评估结果:
# PersonR: 0.799548
# R2: 0.620025
# Explained Variance: 0.620976
# RMSE: 2.254659
# MAE: 1.793867
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.913234
# R2: 0.831334
# Explained Variance: 0.831471
# RMSE: 2.032669
# MAE: 1.472223
# MAPE: nan
# 模型的评估结果:
# PersonR: 0.944245
# R2: 0.889769
# Explained Variance: 0.889796
# RMSE: 1.839200
# MAE: 1.331481
# MAPE: nan
# [ 0.35135757  0.414335    0.46861982  0.36566649  0.35134128  0.49592969
#   0.49704654  0.49107207  0.45190567  0.37204979  0.26178882  0.2775577
#   0.39703242  0.55633558  0.5833517   0.62262965  0.54342642  0.55586232
#   0.49225554  0.51372679  0.60816269  0.63773579  0.66052825  0.70819246
#   0.68595436  0.72442173  0.71176314  0.75819218  0.71413787  0.72282059
#   0.74803267  0.74686697  0.74703079  0.72345932  0.72897444  0.69782913
#   0.6434005   0.7132442   0.67282997  0.61267103 -0.05266051 -0.08938523
#  -0.00729935 -0.03928235  0.0918074   0.12120512  0.0842394   0.08755301
#   0.08528053  0.08803037  0.17390746  0.26352931  0.17258806  0.14151309
#   0.09855752  0.05707496  0.0278826   0.01930849  0.0677044   0.10527697
#  -0.12398514 -0.06601633  0.1061382   0.11453235  0.15088434  0.098216
#   0.1880497   0.33222578  0.36273803  0.35162279  0.35969059  0.23618115
#   0.21299254  0.19493816  0.17971989  0.17860582  0.01158447  0.00839297
#   0.12809557  0.13359909  0.92574276  0.88113712  0.82047214  0.79512173
#   0.75011148  0.75685611  0.77395451  0.78008717  0.80598725  0.77793117
#   0.75471933  0.75468559  0.73870339  0.74332804  0.72980333  0.69305577
#   0.66017397  0.66167371  0.67088535  0.62288582  0.57144007  0.54542895
#   0.52103541  0.54834539  0.4901452   0.45397461  0.44702239  0.47094136
#   0.62941852  0.65548698  0.67197867  0.65998086  0.6715594   0.57403112
#   0.45487049  0.39164926  0.42970439  0.49034254  0.63367921  0.6854638
#  -0.32632475 -0.32326634 -0.21857841 -0.12554701 -0.13089628 -0.07233336
#   0.00513528 -0.02399119  0.01324657 -0.02639389  0.03362005  0.01631164
#   0.02017292 -0.01648458  0.03781556  0.05916587  0.02960056  0.01200256
#   0.0449085   0.22815722  0.25098354  0.34415496  0.35432687  0.21196245
#   0.06954441  0.03008932  0.14434313  0.34383024  0.55184809  0.62062195
#   0.47226545  0.302672    0.16428832  0.16360381  0.24367291  0.27715183
#   0.26499892  0.56174186  0.78300078  0.83500432  0.53733453  0.57480102
#   0.4745214   0.29139482  0.22398825  0.37518992  0.45288628  0.61009038
#   0.60669792  0.44524145  0.33414082  0.39162891  0.33463998  0.31563978
#   0.2611037   0.27159168  0.26812599  0.40164123  0.52169665  0.48014147
#   0.41865608  0.45695707  0.34348802  0.297049    0.20839686  0.29760266
#   0.41898668  0.46300814  0.3044316   0.24535093  0.23846878  0.15336453
#   0.26332132  0.1779882   0.02960966 -0.15270219 -0.01734351  0.49920613
#   0.75337798  0.79915942 -0.38507088 -0.5308193  -0.44906333 -0.6545303
#  -0.62208605 -0.21121699 -0.12181099  0.14188577  0.09169305  0.20991687
#  -0.07709964 -0.09465555 -0.18662375 -0.11326686 -0.0395585  -0.15081095
#  -0.50632642 -0.53834188 -0.3546299  -0.39879146 -0.49268821 -0.23304172
#   0.07900069 -0.09190017 -0.40494917 -0.39901569 -0.22320888 -0.4695024
#  -0.29300483 -0.18384992 -0.49065481 -0.70978831 -0.62717651 -0.50187063
#  -0.480235   -0.52221459 -0.50869545 -0.50270058 -0.32352265 -0.16640931
#   0.25545005  0.22587988  0.37533804  0.52712249  0.47218679  0.48173091
#   0.52091262  0.43058527  0.48022422  0.4461154   0.47310064  0.44094617
#   0.12856942  0.36850351  0.44178202  0.44955714  0.4801978   0.270942
#   0.33939553  0.40306409  0.29242661  0.41110418  0.5510112   0.44804301
#   0.50676493  0.49493425  0.61528636  0.64643598  0.57000696  0.58877473
#   0.58506853  0.50756552  0.53456687  0.60215872  0.58423044  0.51772876
#   0.36279399  0.1904071   0.41869512  0.4671415  -0.08968061 -0.37195078
#  -0.34523691 -0.31393231 -0.04532309  0.15640595 -0.09646313  0.18885638
#   0.07845722  0.04886458  0.09874701  0.10125164  0.26903256  0.09896453
#   0.00901708  0.24076078  0.32627424  0.2711      0.11633954  0.24799875
#   0.09145421  0.24780603  0.26566587  0.23924206  0.24468964  0.35268712
#   0.04540354  0.13583075  0.12157475  0.3569862   0.4225435   0.14536126
#   0.34699073 -0.01384547 -0.23841203 -0.38707957 -0.1257806   0.017876
#  -0.19976795 -0.1788377  -0.17679523 -0.23502603 -0.1680777  -0.12037979
#  -0.12415198 -0.09804256 -0.08464094 -0.12880115 -0.16543173 -0.27727748
#   0.04445568  0.01229193 -0.31225472 -0.0816833  -0.09274328  0.32158629
#   0.00177799  0.30568687  0.17786858  0.12295269  0.01305104 -0.05978674
#   0.00252416 -0.00922241 -0.10904999  0.00915721  0.07833063  0.03369842
#   0.09388879  0.23571642  0.27237509  0.31171872  0.21555456  0.17055961
#   0.20258253  0.3092073   0.3821478   0.24595479  0.03055732 -0.03436755
#   0.13633086  0.12145556 -0.06989011  0.13368822  0.07502102  0.19761616
#   0.38106337  0.11849567 -0.14031556  0.00127815  0.00959436  0.35354764
#   0.13024395  0.23128084  0.28832701  0.08109994 -0.0669746  -0.06767153
#  -0.00253512 -0.13513283  0.03760832 -0.05075257 -0.10597359 -0.00899813
#  -0.05352906  0.01010754 -0.22376118 -0.26274765 -0.29512845 -0.35187197
#  -0.17491034 -0.12108945 -0.20637268 -0.20185283 -0.13586359 -0.1622423
#  -0.09765704  0.04774605 -0.11900852  0.12649328  0.93840626  0.93174431
#   0.92242544  0.93489034  0.95992894  0.97091089  0.94666743  0.92384503
#   0.91421526  0.88686081  0.89798017  0.91154959  0.94083819  0.92647504
#   0.88366882  0.8755417   0.90839547  0.94039488  0.9489445   0.95032561
#   0.95581861  0.97346904  0.96176138  0.96934774  0.97833609  0.97582305
#   0.97542744  0.98234759  0.97855227  0.98119028  0.98009327  0.9774508
#   0.97316635  0.97996998  0.97691309  0.97274714  0.96813603  0.96986884
#   0.97693562  0.97892384  0.89652046  0.91278212  0.92402413  0.95057012
#   0.9317317   0.92472339  0.93618118  0.92331227  0.93435209  0.93156841
#   0.93157698  0.91657702  0.93636322  0.93018557  0.93039821  0.91962718
#   0.92156715  0.93900479  0.91341271  0.91350147  0.93314788  0.94042439
#   0.9506736   0.93879278  0.95930507  0.95560635  0.94735848  0.95954079
#   0.95108785  0.93511075  0.92731182  0.93916576  0.95113932  0.95010577
#   0.9479063   0.95500035  0.94523581  0.91384165  0.93263258  0.91007392
#   0.92256623  0.94074249  0.95368364  0.9532057   0.93299513  0.95018947
#   0.93334379  0.94979719  0.95715993  0.95238807  0.94228089  0.92150085
#   0.92084402  0.92413059  0.94230182  0.95166233  0.94758436  0.9436063
#   0.95240092  0.94846644  0.93318928  0.94619065  0.92529798  0.9090925
#   0.87865775  0.8314466   0.86848649  0.88877829  0.89282266  0.88178389
#   0.88838691  0.90038868  0.90892506  0.88068066  0.84714314  0.75426718
#   0.82020249  0.77388057  0.84090928  0.90286224  0.96028159  0.95128813
#   0.97222905  0.96896705  0.97595535  0.9783039   0.97850698  0.96801602
#   0.96714359  0.96992604  0.96376738  0.95905534  0.96361279  0.9503203
#   0.95317278  0.95798394  0.97041421  0.95495444  0.94396677  0.92785099
#   0.90488071  0.80411432  0.77684534  0.88272601  0.90218748  0.93321688
#   0.93437738  0.93812617  0.95047908  0.95590001  0.96743389  0.96440305
#   0.95219349  0.96120935  0.96046757  0.97150721  0.96071436  0.96307905
#   0.97884185  0.98366761  0.94457644  0.95277736  0.96264823  0.9724555
#   0.96300768  0.95923908  0.94762769  0.94967409  0.95552666  0.96091719
#   0.95689194  0.9439408   0.91689158  0.92472914  0.92641977  0.95558973
#   0.9442069   0.94626266  0.96297965  0.95625299  0.94245306  0.91930097
#   0.93292473  0.92752154  0.94255747  0.95834331  0.95022028  0.95477521
#   0.95510396  0.94653263  0.947287    0.95276563  0.95683992  0.92377995
#   0.92960903  0.93671319  0.9238325   0.95417823  0.98037748  0.98715086
#   0.87677603  0.84394151  0.85974772  0.85737319  0.90159011  0.92246205
#   0.89265982  0.88213045  0.81194865  0.84537272  0.82092348  0.84085531
#   0.88284963  0.86210375  0.86469262  0.80571003  0.88273857  0.8925654
#   0.91546429  0.91630367  0.8997805   0.90417898  0.92829956  0.91956931
#   0.9328073   0.94610562  0.94418645  0.96752901  0.95931878  0.96368184
#   0.94440972  0.95101176  0.94188145  0.9472272   0.94708919  0.93308807
#   0.9213463   0.91872353  0.95122155  0.94453944  0.85391256  0.81269555
#   0.83549362  0.90300393  0.90867349  0.87627012  0.82984811  0.82512404
#   0.83599826  0.83830058  0.86321626  0.87534694  0.86172669  0.84797188
#   0.83364605  0.82090965  0.84111324  0.84821384  0.84056682  0.86245836
#   0.85657791  0.82056327  0.8739682   0.89600687  0.90638518  0.91207927
#   0.89526     0.9227328   0.93432752  0.91266124  0.88905971  0.88771714
#   0.91558997  0.92762137  0.90128027  0.92814806  0.92461144  0.90845222
#   0.88570138  0.89097037  0.93450509  0.94846087  0.94901699  0.94442956
#   0.9504781   0.95214522  0.9435134   0.95155578  0.94144773  0.94072449
#   0.93877487  0.91079172  0.92291695  0.88383587  0.90922137  0.94710351
#   0.95160639  0.96410348  0.94682733  0.94813393  0.94385681  0.92857177
#   0.95390807  0.92011749  0.89316372  0.88508317  0.86448089  0.88105388
#   0.89934484  0.90558523  0.91955131  0.93074791  0.93862796  0.90661005
#   0.89711793  0.83860123  0.8549097   0.75738736  0.8846915   0.90992227
#   0.74055992  0.74805028  0.76313221  0.81771815  0.83702274  0.84046349
#   0.81722076  0.78315536  0.78571422  0.79633276  0.79322294  0.79408907
#   0.83168368  0.83418088  0.8473169   0.86583363  0.88467665  0.82862737
#   0.79097653  0.8307081   0.71993962  0.56221506  0.48168943  0.56731874
#   0.55859667  0.66919545  0.76982861  0.79204487  0.85457218  0.86382514
#   0.84823191  0.83370578  0.7902498   0.79343054  0.80377524  0.83785784
#   0.76359822  0.8416964   0.90442615  0.92591392  0.82698065  0.83511036
#   0.87643132  0.87469326  0.87051206  0.84768441  0.85074502  0.83696304
#   0.88024416  0.87220494  0.87327737  0.80763515  0.734605    0.81442547
#   0.81627192  0.8465789   0.8062887   0.79387943  0.86779251  0.87090674
#   0.85240466  0.71204505  0.73084436  0.83050787  0.82934036  0.80594335
#   0.81361776  0.84112     0.83501583  0.80821546  0.76227094  0.72288586
#   0.74445677  0.78350585  0.78508595  0.73324645  0.65597435  0.79954755
#   0.9132341   0.9442445 ]
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide
# /home/liuli/anaconda3/envs/JT/lib/python3.7/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide

# %%
#ts=ts.reshape(4,5,40)
m0=m0.reshape(4,5,40)
m3=m3.reshape(4,5,40)
m4=m4.reshape(4,5,40)
#ts_sta=np.array([])
m0_sta=np.array([])
m3_sta=np.array([])
m4_sta=np.array([])

for nn in range(0,5):
    m0_sta=np.append(m0_sta,np.max(m0[:,nn,:],axis=0))
    m3_sta=np.append(m3_sta,np.min(m3[:,nn,:],axis=0))
    m4_sta=np.append(m4_sta,np.min(m4[:,nn,:],axis=0))
    #ts_sta=np.append(ts_sta,np.max(ts[:,nn,:],axis=0))
    
#ts_sta=ts_sta.reshape(5,-1)
m0_sta=m0_sta.reshape(5,-1)
m3_sta=m3_sta.reshape(5,-1)
m4_sta=m4_sta.reshape(5,-1)
print(m0_sta)
# Out:
# [[0.93840626 0.93174431 0.92242544 0.93489034 0.95992894 0.97091089
#   0.94666743 0.92384503 0.91421526 0.88686081 0.89798017 0.91154959
#   0.94083819 0.92647504 0.88366882 0.8755417  0.90839547 0.94039488
#   0.9489445  0.95032561 0.95581861 0.97346904 0.96176138 0.96934774
#   0.97833609 0.97582305 0.97542744 0.98234759 0.97855227 0.98119028
#   0.98009327 0.9774508  0.97316635 0.97996998 0.97691309 0.97274714
#   0.96813603 0.96986884 0.97693562 0.97892384]
#  [0.89652046 0.91278212 0.92402413 0.95057012 0.9317317  0.92472339
#   0.93618118 0.92331227 0.93435209 0.93156841 0.93157698 0.91657702
#   0.93636322 0.93018557 0.93039821 0.91962718 0.92156715 0.93900479
#   0.91341271 0.91350147 0.93314788 0.94042439 0.9506736  0.93879278
#   0.95930507 0.95560635 0.94735848 0.95954079 0.95108785 0.93511075
#   0.92731182 0.93916576 0.95113932 0.95010577 0.9479063  0.95500035
#   0.94523581 0.91384165 0.93263258 0.91007392]
#  [0.93450509 0.94846087 0.95368364 0.9532057  0.9504781  0.95214522
#   0.9435134  0.95155578 0.95715993 0.95238807 0.94228089 0.92150085
#   0.92291695 0.92413059 0.94230182 0.95166233 0.95160639 0.96410348
#   0.95240092 0.94846644 0.94385681 0.94619065 0.95390807 0.92011749
#   0.89316372 0.88508317 0.86848649 0.88877829 0.89934484 0.90558523
#   0.91955131 0.93074791 0.93862796 0.90661005 0.89711793 0.83860123
#   0.8549097  0.77388057 0.8846915  0.90992227]
#  [0.96028159 0.95128813 0.97222905 0.96896705 0.97595535 0.9783039
#   0.97850698 0.96801602 0.96714359 0.96992604 0.96376738 0.95905534
#   0.96361279 0.9503203  0.95317278 0.95798394 0.97041421 0.95495444
#   0.94396677 0.92785099 0.90488071 0.80411432 0.77684534 0.88272601
#   0.90218748 0.93321688 0.93437738 0.93812617 0.95047908 0.95590001
#   0.96743389 0.96440305 0.95219349 0.96120935 0.96046757 0.97150721
#   0.96071436 0.96307905 0.97884185 0.98366761]
#  [0.94457644 0.95277736 0.96264823 0.9724555  0.96300768 0.95923908
#   0.94762769 0.94967409 0.95552666 0.96091719 0.95689194 0.9439408
#   0.91689158 0.92472914 0.92641977 0.95558973 0.9442069  0.94626266
#   0.96297965 0.95625299 0.94245306 0.91930097 0.93292473 0.92752154
#   0.94255747 0.95834331 0.95022028 0.95477521 0.95510396 0.94653263
#   0.947287   0.95276563 0.95683992 0.92377995 0.92960903 0.93671319
#   0.9238325  0.95417823 0.98037748 0.98715086]]

# %%
#out=pd.DataFrame(ts_sta)
out=pd.DataFrame(m0_sta)
out3=pd.DataFrame(m3_sta)
out4=pd.DataFrame(m4_sta)
# 自定义map函数
def test_map(x):
    return 'sta_%i' %(x+1)
out=out.rename(index=test_map)
out3=out3.rename(index=test_map)
out4=out4.rename(index=test_map)
out.to_csv('wave_R.csv',sep=',')
out3.to_csv('wave_RMSE.csv',sep=',')
out4.to_csv('wave_MAE.csv',sep=',')

# %%
from matplotlib.pyplot import MultipleLocator

plt.figure(figsize=(18,10))
plt.plot( out.loc['sta_1'].values,'g-',linewidth=1.5)
plt.plot( out.loc['sta_2'].values,'r:', linewidth=1.5)
plt.plot( out.loc['sta_3'].values,'b-', linewidth=1.5)
plt.plot( out.loc['sta_4'].values,'k:', linewidth=1.5)
plt.plot( out.loc['sta_5'].values,'c-.', linewidth=1.5)

plt.legend(labels=['sta_1','sta_2','sta_3','sta_4','sta_5'], loc=2, prop={'size': 15}, ncol=5, framealpha=0.3)
plt.tick_params(labelcolor='k', labelsize='15', width=1.5)
#plt.ylabel("TS",fontsize=15)
plt.ylabel("R",fontsize=15)
#ax1.xaxis.set_major_locator(mpl.ticker.MultipleLocator(30))#设定坐标轴的显示的刻度间隔
x_major_locator=MultipleLocator(5)
#把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(0.2)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
#plt.xlim(-0.5,40)
#把x轴的刻度范围设置为-0.5到11，因为0.5不满一个刻度间隔，所以数字不会显示出来，但是能看到一点空白
#plt.ylim(0.6,1.1)
#把y轴的刻度范围设置为-5到110，同理，-5不会标出来，但是能看到一点空白
plt.savefig("wave_R.png",dpi=100)
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.plot( out3.loc['sta_1'].values,'g-',linewidth=1.5)
plt.plot( out3.loc['sta_2'].values,'r:', linewidth=1.5)
plt.plot( out3.loc['sta_3'].values,'b-', linewidth=1.5)
plt.plot( out3.loc['sta_4'].values,'k:', linewidth=1.5)
plt.plot( out3.loc['sta_5'].values,'c-.', linewidth=1.5)

plt.legend(labels=['sta_1','sta_2','sta_3','sta_4','sta_5'], loc=2, prop={'size': 15}, ncol=5, framealpha=0.3)
plt.tick_params(labelcolor='k', labelsize='15', width=1.5)
#plt.ylabel("TS",fontsize=15)
plt.ylabel("RMSE",fontsize=15)
#ax1.xaxis.set_major_locator(mpl.ticker.MultipleLocator(30))#设定坐标轴的显示的刻度间隔
x_major_locator=MultipleLocator(5)
#把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(0.2)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
#plt.xlim(-0.5,40)
#把x轴的刻度范围设置为-0.5到11，因为0.5不满一个刻度间隔，所以数字不会显示出来，但是能看到一点空白
#plt.ylim(0.6,1.1)
#把y轴的刻度范围设置为-5到110，同理，-5不会标出来，但是能看到一点空白
plt.savefig("wave_RMSE.png",dpi=100)
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.plot( out4.loc['sta_1'].values,'g-',linewidth=1.5)
plt.plot( out4.loc['sta_2'].values,'r:', linewidth=1.5)
plt.plot( out4.loc['sta_3'].values,'b-', linewidth=1.5)
plt.plot( out4.loc['sta_4'].values,'k:', linewidth=1.5)
plt.plot( out4.loc['sta_5'].values,'c-.', linewidth=1.5)

plt.legend(labels=['sta_1','sta_2','sta_3','sta_4','sta_5'], loc=2, prop={'size': 15}, ncol=5, framealpha=0.3)
plt.tick_params(labelcolor='k', labelsize='15', width=1.5)
#plt.ylabel("TS",fontsize=15)
plt.ylabel("MAE",fontsize=15)
#ax1.xaxis.set_major_locator(mpl.ticker.MultipleLocator(30))#设定坐标轴的显示的刻度间隔
x_major_locator=MultipleLocator(5)
#把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(0.2)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
#plt.xlim(-0.5,40)
#把x轴的刻度范围设置为-0.5到11，因为0.5不满一个刻度间隔，所以数字不会显示出来，但是能看到一点空白
#plt.ylim(0.6,1.1)
#把y轴的刻度范围设置为-5到110，同理，-5不会标出来，但是能看到一点空白
plt.savefig("wave_MAE.png",dpi=100)
plt.show()
