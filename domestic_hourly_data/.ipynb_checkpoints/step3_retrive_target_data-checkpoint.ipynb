# %% [markdown]
# #1.根据statistics_valid_data.txt，针对每一个要素删选出排名前300的站点
# #2.每一个要素一个文件，生成完整的3-hourly时间序列。

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import datetime
import pandas as pd
txt_path='/home/liuli/GTS_GFS_MOS/domestic_hourly_data/statistics_valid_data_0.8.txt'
file1= pd.read_csv(txt_path,sep='\t',header=None,names=['sta','para','rate'])
df1=pd.DataFrame(file1)
print(df1.info())
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 3 columns):
# sta     21864 non-null object
# para    21864 non-null object
# rate    21864 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 512.5+ KB
# None
#            sta  para      rate
# 0        56341    ps  0.867511
# 1        56341   psl  0.867511
# 2        56341   t2m  0.867511
# 3        56341    td  0.867511
# 4        56341  wdir  0.867511
# 5        56341  wspd  0.867511
# 6        23095   psl  0.897980
# 7        23095   t2m  0.903458
# 8        23095  wdir  0.818213
# 9        23460   psl  0.883602
# 10       23460   t2m  0.884286
# 11       23460  wdir  0.820952
# 12       99217    ps  0.857241
# 13       99217   psl  0.857241
# 14       99217   t2m  0.857241
# 15       99217    td  0.857241
# 16       99217  wdir  0.857241
# 17       99217  wspd  0.857241
# 18       54418    ps  0.934269
# 19       54418   psl  0.918863
# 20       54418   t2m  0.935296
# 21       54418    td  0.935296
# 22       54418  wdir  0.935296
# 23       54418  wspd  0.935296
# 24       54544    ps  0.947963
# 25       54544   psl  0.931873
# 26       54544   t2m  0.941116
# 27       54544    td  0.941116
# 28       54544  wdir  0.947963
# 29       54544  wspd  0.947963
# ...        ...   ...       ...
# 21834    22189   t2m  0.954810
# 21835    22189  wdir  0.954810
# 21836    22189  wspd  0.954810
# 21837  5200003   t2m  0.888737
# 21838  5200003    td  0.888737
# 21839  5200003  wspd  0.888737
# 21840    22107   psl  0.975693
# 21841    22107   t2m  0.975693
# 21842    22107  wdir  0.975693
# 21843    22107  wspd  0.975693
# 21844    22106   psl  0.859979
# 21845    22106   t2m  0.859979
# 21846    22106  wdir  0.859979
# 21847    22106  wspd  0.859979
# 21848    22108   psl  0.972954
# 21849    22108   t2m  0.972954
# 21850    22108  wdir  0.972954
# 21851    22108  wspd  0.972954
# 21852    22184   psl  0.982883
# 21853    22184   t2m  0.982883
# 21854    22184  wdir  0.982883
# 21855    22184  wspd  0.982883
# 21856    22183   psl  0.961315
# 21857    22183   t2m  0.961315
# 21858    22183  wdir  0.961315
# 21859    22183  wspd  0.961315
# 21860    22185   psl  0.944197
# 21861    22185   t2m  0.944197
# 21862    22185  wdir  0.944197
# 21863    22185  wspd  0.944197
#
# [21864 rows x 3 columns]

# %%
data_path='/home/liuli/GTS_GFS_MOS/domestic_hourly_data/df_final_2400.csv'
file0= pd.read_csv(data_path,sep=',')
df0=pd.DataFrame(file0)
df0=df0.replace(999999.0, np.nan) 
df0=df0.replace(999998.0, np.nan)
df0=df0.replace(9999.0, np.nan)
df0['sta']=df0['sta'].astype('str')
#df0['sta']=df0['sta'].replace('NaN','53603')
df0['time']=pd.DatetimeIndex(df0['time'])

start='2018-01-01 00:00:00'
end_of_db = '2019-01-01 00:00:00'
date_index = pd.date_range(start, end_of_db, freq = '3h')
date_df = pd.DataFrame(date_index,columns=['time'])
df0 = pd.merge(date_df,df0, on=['time'], how='left') 


print(df0.info())
print(df0.count())
df0
# Out:
# /home/liuli/anaconda3/envs/MOS/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10915777 entries, 0 to 10915776
# Data columns (total 14 columns):
# time    datetime64[ns]
# sta     object
# ht      float64
# lat     float64
# lon     float64
# pr1     float64
# pr24    float64
# pr6     float64
# ps      float64
# psl     float64
# t2m     float64
# td      float64
# wdir    float64
# wspd    float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 1.2+ GB
# None
# time    10915777
# sta     10915777
# ht      10518360
# lat     10734800
# lon     10734800
# pr1        28408
# pr24     7727138
# pr6      7746692
# ps      10361007
# psl     10360860
# t2m     10704643
# td      10420364
# wdir    10699099
# wspd    10699276
# dtype: int64
#                time      sta      ht    lat     lon  pr1  pr24  pr6      ps  \
# 0        2018-01-01    45004    66.4  22.31  114.17  NaN   0.0  0.0  1013.6
# 1        2018-01-01    45005    31.7  22.30  114.17  NaN   0.0  0.0  1016.7
# 2        2018-01-01     FVNM     NaN   7.30  134.50  NaN   NaN  NaN     NaN
# 3        2018-01-01    52006     NaN   8.10  165.10  NaN   NaN  NaN     NaN
# 4        2018-01-01  5200006     NaN   8.10  165.10  NaN   NaN  NaN     NaN
# 5        2018-01-01    56341  2487.0  29.77   99.01  0.0   NaN  NaN   752.9
# 6        2018-01-01    21547     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 7        2018-01-01     DBBE     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 8        2018-01-01    23095     NaN  10.46   94.01  NaN   NaN  NaN     NaN
# 9        2018-01-01    23460     NaN   6.57   88.21  NaN   NaN  NaN     NaN
# 10       2018-01-01    99217   210.0  39.63  124.45  0.0   0.0  0.0  1024.6
# 11       2018-01-01    54418     1.5  38.56  117.58  0.0   NaN  NaN  1026.4
# 12       2018-01-01    54544     5.2  39.57  119.28  0.0   NaN  NaN  1028.3
# 13       2018-01-01    54647     2.0  39.18  118.90  0.0   NaN  NaN  1028.4
# 14       2018-01-01    54720     4.0  38.46  117.71  0.0   NaN  NaN  1027.0
# 15       2018-01-01    54721     3.5  38.34  117.88  0.0   NaN  NaN  1026.7
# 16       2018-01-01     JPBN     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 17       2018-01-01    53321  1496.0  41.81  107.52  NaN   NaN  NaN   849.2
# 18       2018-01-01     JGQH     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 19       2018-01-01    54655   122.4  38.39  120.91  0.0   NaN  NaN  1013.7
# 20       2018-01-01  2800401     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 21       2018-01-01  2300008     NaN  12.04   88.79  NaN   NaN  NaN     NaN
# 22       2018-01-01    23459     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 23       2018-01-01    57403   354.0  30.59  105.23  0.0   0.0  0.0   978.6
# 24       2018-01-01    51862   857.0  38.70   87.41  0.0   NaN  NaN   908.9
# 25       2018-01-01     VWFQ     NaN  13.10   80.30  NaN   NaN  NaN     NaN
# 26       2018-01-01    54773    25.9  37.41  122.59  0.0   NaN  NaN  1025.4
# 27       2018-01-01    51158   573.0  46.34   86.22  0.0   NaN  NaN   965.2
# 28       2018-01-01    51523     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 29       2018-01-01    51323  1903.0  44.96   80.58  0.0   NaN  NaN   812.4
# ...             ...      ...     ...    ...     ...  ...   ...  ...     ...
# 10915747 2019-01-01    98558     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915748 2019-01-01    98646     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915749 2019-01-01    98648     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915750 2019-01-01    98653     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915751 2019-01-01  AMOHK02     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915752 2019-01-01    46770     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915753 2019-01-01    52200     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915754 2019-01-01    52087     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915755 2019-01-01    52003     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915756 2019-01-01    52202     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915757 2019-01-01    52201     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915758 2019-01-01    22103     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915759 2019-01-01    22102     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915760 2019-01-01    22105     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915761 2019-01-01    22101     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915762 2019-01-01    21229     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915763 2019-01-01    22104     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915764 2019-01-01  5200087     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915765 2019-01-01    22187     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915766 2019-01-01    22186     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915767 2019-01-01    22188     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915768 2019-01-01    22190     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915769 2019-01-01    22189     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915770 2019-01-01  5200003     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915771 2019-01-01    22107     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915772 2019-01-01    22106     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915773 2019-01-01    22108     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915774 2019-01-01    22184     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915775 2019-01-01    22183     NaN    NaN     NaN  NaN   NaN  NaN     NaN
# 10915776 2019-01-01    22185     NaN    NaN     NaN  NaN   NaN  NaN     NaN
#
#              psl    t2m    td   wdir  wspd
# 0         1021.5  15.90  12.1  120.0   2.0
# 1         1021.5  16.60  12.9   80.0   4.0
# 2         1008.4  29.00  23.9  190.0   2.0
# 3            NaN  28.40   NaN   70.0   6.0
# 4            NaN  28.42  24.1   68.0   5.8
# 5         1016.1   4.20 -15.7  198.0   1.8
# 6            NaN    NaN   NaN    NaN   NaN
# 7            NaN    NaN   NaN    NaN   NaN
# 8         1008.2  28.00   NaN   90.0   9.0
# 9         1007.3  25.50   NaN   80.0   5.0
# 10        1082.4 -12.00   0.0   64.0   2.3
# 11        1026.7  -3.20  -6.5   39.0   1.8
# 12        1029.1  -0.80  -9.0   73.0   9.8
# 13        1028.8  -4.10  -6.1   65.0   3.6
# 14        1027.7  -0.10  -4.5   97.0   2.0
# 15        1027.3  -1.10  -5.2  152.0   1.6
# 16           NaN    NaN   NaN    NaN   NaN
# 17        1032.1 -15.30 -19.7  155.0   3.4
# 18           NaN    NaN   NaN    NaN   NaN
# 19        1029.3   2.30  -7.9  341.0   1.3
# 20           NaN    NaN   NaN    NaN   NaN
# 21           NaN  27.70   NaN  156.0   3.0
# 22           NaN    NaN   NaN    NaN   NaN
# 23        1021.9   3.10   2.4  205.0   1.1
# 24           NaN -13.10   NaN   57.0   1.1
# 25        1008.3  24.00   NaN  320.0   4.0
# 26        1028.9   1.20 -12.9  218.0   2.0
# 27           NaN -14.30   NaN   85.0   0.7
# 28           NaN    NaN   NaN    NaN   NaN
# 29           NaN -14.60   NaN  190.0   1.0
# ...          ...    ...   ...    ...   ...
# 10915747     NaN    NaN   NaN    NaN   NaN
# 10915748     NaN    NaN   NaN    NaN   NaN
# 10915749     NaN    NaN   NaN    NaN   NaN
# 10915750     NaN    NaN   NaN    NaN   NaN
# 10915751     NaN    NaN   NaN    NaN   NaN
# 10915752     NaN    NaN   NaN    NaN   NaN
# 10915753     NaN    NaN   NaN    NaN   NaN
# 10915754     NaN    NaN   NaN    NaN   NaN
# 10915755     NaN    NaN   NaN    NaN   NaN
# 10915756     NaN    NaN   NaN    NaN   NaN
# 10915757     NaN    NaN   NaN    NaN   NaN
# 10915758     NaN    NaN   NaN    NaN   NaN
# 10915759     NaN    NaN   NaN    NaN   NaN
# 10915760     NaN    NaN   NaN    NaN   NaN
# 10915761     NaN    NaN   NaN    NaN   NaN
# 10915762     NaN    NaN   NaN    NaN   NaN
# 10915763     NaN    NaN   NaN    NaN   NaN
# 10915764     NaN    NaN   NaN    NaN   NaN
# 10915765     NaN    NaN   NaN    NaN   NaN
# 10915766     NaN    NaN   NaN    NaN   NaN
# 10915767     NaN    NaN   NaN    NaN   NaN
# 10915768     NaN    NaN   NaN    NaN   NaN
# 10915769     NaN    NaN   NaN    NaN   NaN
# 10915770     NaN    NaN   NaN    NaN   NaN
# 10915771     NaN    NaN   NaN    NaN   NaN
# 10915772     NaN    NaN   NaN    NaN   NaN
# 10915773     NaN    NaN   NaN    NaN   NaN
# 10915774     NaN    NaN   NaN    NaN   NaN
# 10915775     NaN    NaN   NaN    NaN   NaN
# 10915776     NaN    NaN   NaN    NaN   NaN
#
# [10915777 rows x 14 columns]

# %%
#每一个要素中，按照rate排名前300来筛选站点
#附属产品：所有6个要素的站点信息，放在一个txt文档里面，为以后GFS提取数据使用
#cols=['ps','psl','t2m','td','wdir','wspd']
cols=['wspd'] #不知道为什么，只能分开输出station信息，合在一起write line会导致写的信息有缺失
print(cols)
#print(df0[df0['sta'].isin(['54578'])].dropna(subset=['lat','lon'],how='any'))
for i in cols:
    name='6-para-station-info-'+i+'.txt'
    f=open(name,'w')
    #df_final=pd.DataFrame(columns=['time','sta','lat','lon',i])
    #print(df_final)
    df2=df1[df1['para'].isin([i])] #先挑出这个要素
    #print('df2=',df2)
    df2=df2.sort_values(by='rate',ascending=False)#把这个站点按照rate顺序排列  
    df2=df2.reset_index(drop=True)
    print(df2.sta[:300])
   
    for j in df2.sta[:300]:   #只挑前300个站点
        #print(j)
        df3=df0[df0['sta'].isin([j])]
        df3=df3.reset_index(drop=True)
        #print('df3=',df3)
        df4=df3[['time','sta','lat','lon',i]]
        df5=df4.dropna(subset=['lat','lon'],how='any')
        df5=df5.reset_index(drop=True)
        #print(df5)
        #print(str(df5.loc[0,'lat']))
        line=[]
        line=str(j)+'\t'+str(df5.loc[0,'lat'])+'\t'+str(df5.loc[0,'lon'])+'\n' #站号、经纬度
        f.write(line)
        #df_final=pd.concat([df_final,df4],ignore_index=True)            
        del df3
        del df4
        del df5
        del line
    #df_final.to_csv('./df_'+i+'.csv', sep=',', header=True, index=False)    
    #del df_final
    del df2
# Out:
# ['wspd']
# 0      51243
# 1      52602
# 2      56944
# 3      56946
# 4      52833
# 5      56948
# 6      52825
# 7      52824
# 8      56954
# 9      52765
# 10     56959
# 11     52707
# 12     52679
# 13     56963
# 14     52674
# 15     56964
# 16     52656
# 17     56967
# 18     52652
# 19     56898
# 20     56891
# 21     56889
# 22     52884
# 23     56863
# 24     56869
# 25     56870
# 26     56871
# 27     52896
# 28     52889
# 29     56875
#        ...
# 270    57053
# 271    51470
# 272    51469
# 273    51467
# 274    57057
# 275    57060
# 276    57070
# 277    51356
# 278    51430
# 279    57071
# 280    51381
# 281    51379
# 282    51378
# 283    57072
# 284    51367
# 285    57128
# 286    57132
# 287    50924
# 288    50618
# 289    50659
# 290    50656
# 291    57186
# 292    50647
# 293    57190
# 294    57192
# 295    50637
# 296    57193
# 297    57181
# 298    50548
# 299    50531
# Name: sta, Length: 300, dtype: object
